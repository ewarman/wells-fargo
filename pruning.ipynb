# %%
#Parses .txt file to python dictionary
import codecs

f = codecs.open('data.txt', 'r', encoding='utf-8', errors='ignore')
line = f.readline()
keys = line.split('|')
#remove '/n/r'
keys[-1] = keys[-1][:-2]
data = []
while True:
    try:
        line = f.readline()
        values = line.split('|')
        msg = dict(zip(keys,values))
        #remove '/n/r'
        msg['FullText'] = msg['FullText'][:-2]
        data.append(msg.copy())
    except KeyError:
        break

import json
with open('wells-fargo-dict.json', 'w') as outfile:
    json.dump(data, outfile)

# %%
#read in data
import json
with open('wells-fargo-dict.json') as data_file:    
    data = json.load(data_file)
    
print('Total messages:', len(data))
# Out:
# Total messages: 220377

# %%
#include only unique messages

prune1 = []
msgs = set()
#go through every msg
for item in data:
    text = item['FullText']
    if text not in msgs:
        msgs.add(text)
        prune1.append(item)
        
print('Messages Remaining:', len(prune1))
# Out:
# Messages Remaining: 206491

# %%
#remove all tweets that cannot be attributed to a bank

bank_words = ['BankA', 'BankB', 'BankC', 'BankD', '#BankA', '#BankB', '#BankC', '#BankD', 'twit_hndl_BankA', 'twit_hndl_BankB', 'twit_hndl_BankC', 'twit_hndl_BankD']
prune2 = []
for item in prune1:
    if any(word in item['FullText'] for word in bank_words):
        prune2.append(item)

print('Messages Remaining:', len(prune2))
# Out:
# Messages Remaining: 186498

# %%
#remove messages of banks responding to customers
prune3 = []
for item in prune2:
    if 'Name_Resp' not in item['FullText']:
        prune3.append(item)
        
print('Messages Remaining:',len(prune3))
# Out:
# Messages Remaining: 183050

# %%
#remove messages from employees and interview candidates
interview_words = ['interview', 'interviews', 'got the job', 'hiring at', 'hired']
prune4 = []
for item in prune3:
    if all(word not in item['FullText'] for word in interview_words):
        prune4.append(item)
print('Messages Remaining:',len(prune4))
# Out:
# Messages Remaining: 182077

# %%
#remove messages about bank sponsored stadiums and arenas
sports_words = ['stadium', 'playoffs', 'arena', 'preseason', 'center for the arts', 'BankA center', 'BankA building', 'game day']
prune5 = []
for item in prune4:
    if all(word not in item['FullText'] for word in sports_words):
        prune5.append(item)
print('Messages Remaining:',len(prune5))
# Out:
# Messages Remaining: 176492

# %%
#remove spam messages about 'mission main street'
prune6 = []
for item in prune5:
    if 'mission main street' not in item['FullText']:
        prune6.append(item)
print('Messages Remaining:',len(prune6))
# Out:
# Messages Remaining: 170886

# %%
#remove messages for #getcollegeready contest
prune7 = []
for item in prune6:
    if 'getcollegeready' not in item['FullText']:
        prune7.append(item)
    else:
        print(item['FullText'])
print('Messages Remaining:',len(prune7))
# Out:
# ??? BankA# getcollegeready# contest
# ???? twit_hndl_BankA please allow me to win this prize!# getcollegeready# contest???? thanks!! have a great day
# . twit_hndl_BankA is celebrating# Name today by giving away BankB packs with prizes. bit. ly/ 1dtrpig# getcollegeready
# twit_hndl_BankA see how to have# budgeting in the bag with these tips to# getcollegeready. INTERNET
# twit_hndl move the conveyor belt-# getcollegeready# contest twit_hndl_BankA
# twit_hndl: twit_hndl_BankA thank you for the chance!! my BankB pack fell!! Name!# getcollegeready# contest# ididit
# twit_hndl fabulous twit_hndl_BankA BankB  to school promo! you should enter it!# getcollegeready# contest
# twit_hndl i love this twit_hndl_BankA BankB  to school promo! you should try it!# getcollegeready# contest
# twit_hndl thanks for joining us for the# getcollegeready contest. email us by 8/13/15 socialmediatwit_hndl_BankA INTERNET for prize instructions.
# twit_hndl twit_hndl_BankA is tweeting the winners so we just gotta keep trying# getcollegeready# contest
# twit_hndl_BankA hope that belt is moving that BankB pack and its heading out west to california to meet me!# getcollegeready# contest
# twit_hndl_BankA i am following BankA and i hope that BankB pack is following me home:- )# getcollegeready# contest
# twit_hndl_BankA wish i was taking a stagecoach to college, but i will settle for a BankB pack!# getcollegeready# contest
# twit_hndl twit_hndl_BankA me too who will be the winner# getcollegeready# contest
# twit_hndl thanks 4 joining the# getcollegeready contest. email us by 8/13/15 at socialmediatwit_hndl_BankA INTERNET 4 prize claim instructions.
# twit_hndl thanks for joining the# getcollegeready contest. email us by 8/13/15 at socialmediatwit_hndl_BankA INTERNET for prize claim instructions.
# twit_hndl thanks for joining the# getcollegeready contest. email us by 8/13/15 socialmediatwit_hndl_BankA INTERNET for prize instructions.
# twit_hndl is today your lucky day? twit_hndl_BankA is giving away BankB packs for 8 hours today! bit. ly/ 1dtrpig# getcollegeready
# twit_hndl: twit_hndl_BankA# getcollegeready# contest
# twit_hndl Name 4 joining the# getcollegeready contest. email us by 8/13/15 at socialmediatwit_hndl_BankA INTERNET 4 prize instructions.
# twit_hndl thanks 4 joining the# getcollegeready contest. email by 8/13/15 at socialmediatwit_hndl_BankA INTERNET 4 prize instructions.
# twit_hndl twit_hndl_BankA# getcollegeready# contest!!!! education is my priority for my kids!!!!
# twit_hndl twit_hndl_BankA i have one who is college ready!!!# getcollegeready# contest INTERNET
# twit_hndl Name crazy down our timeline# pickheralready twit_hndl_BankA# getcollegeready# contest
# twit_hndl thanks for joining the# getcollegeready contest. email us by 8/13/15 at socialmediatwit_hndl_BankA INTERNET for prize instructions.
# twit_hndl good luck! thank you for the fabulous twit_hndl_BankA BankB  to school promo! you should enter it!# getcollegeready# contest
# twit_hndl thanks for joining us 4 the# getcollegeready contest. email us by 8/13/15 socialmediatwit_hndl_BankA INTERNET for prize instructions.
# twit_hndl they are twit_hndl_BankA# getcollegeready# contest
# twit_hndl the conveyor belt w/ twit_hndl_BankA# getcollegeready# contest Name the conveyor belt. spr. ly/ 6016beBankC2 INTERNET
# twit_hndl: twit_hndl_BankA# getcollegeready# contest Name an active member! INTERNET
# twit_hndl thanks for joining us the# getcollegeready contest. email us by 8/13/15 socialmediatwit_hndl_BankA INTERNET for prize instructions.
# twit_hndl twit_hndl_BankA# getcollegeready# contest INTERNET
# twit_hndl twit_hndl_BankA please let this be the tweet that makes it fall.# getcollegeready# contest
# twit_hndl twit_hndl_BankA you won my heart.# getcollegeready# contest
# twit_hndl move the BankB pack with me# getcollegeready# contest twit_hndl_BankA
# twit_hndl making sure you got my dir_msg-# getcollegeready twit_hndl_BankA# contest
# twit_hndl twit_hndl_BankA that sucks/ thought it was Name- thanks for the chance twit_hndl_BankA# getcollegeready congrats all winners
# twit_hndl twit_hndl_BankA twit_hndl you could win a prize.# getcollegeready# contest spr. ly/ 6016beBankC2 INTERNET
# twit_hndl twit_hndl_BankA move the conveyor belt..# getcollegeready# contest spr. ly/ 6016beBankC2 INTERNET
# twit_hndl twit_hndl twit_hndl_BankA im tweeting it up i wanna win too!# getcollegeready# contest did they stop the contest?
# twit_hndl twit_hndl_BankA# getcollegeready# contest Name ok with it
# twit_hndl twit_hndl_BankA Name a grandma# getcollegeready# contest
# twit_hndl twit_hndl_BankA larry# getcollegeready is# contest real
# twit_hndl thanks for joining us for the# getcollegeready contest. email us by 8/13/15 at socialmediatwit_hndl_BankA INTERNET for prize instructions.
# twit_hndl_BankA Name with# getcollegeready and# contest Name your tweet drops the BankB pack into the box, you win the prize inside
# twit_hndl_BankA thank so much for the chance, we love BankA!!!!!!# getcollegeready# contest
# twit_hndl_BankA?? 1 little, 2 little BankB packs, hoping to win the last one....??!!!!# getcollegeready# contest
# twit_hndl_BankA cmon conveyor belt belt, lol!!!??????# getcollegeready# contest
# twit_hndl_BankA falling?# getcollegeready# contest
# twit_hndl_BankA fingers crossed, thanks for the chance!# getcollegeready# contest
# twit_hndl_BankA going to keep tweeting till i cant go any longer(or until the contest ends, lol ).# getcollegeready# contest
# twit_hndl_BankA i don  t know what  s harder  college or trying to win these prizes.# getcollegeready# contest
# twit_hndl_BankA Name loving all of these tweets, this is a fun# contest!!!! good luck everyone.# getcollegeready
# twit_hndl_BankA Name running out of tweet ideas, but i cant stop until i win,(hopefully )!# getcollegeready# contest
# twit_hndl_BankA Name tweeting my way to a BankB pack!!# getcollegeready# contest
# twit_hndl_BankA inching, inching to that carton and off i go to meet twit_hndl# getcollegeready# contest
# twit_hndl_BankA Name, my kids are already fighting over this BankB pack!# getcollegeready# contest INTERNET
# twit_hndl_BankA pretty please with a BankB pack on top!# getcollegeready# contest
# twit_hndl_BankA so ready!# getcollegeready
# twit_hndl_BankA Name conveyor belt in my heart has fallen in love with this BankB pack!!!# getcollegeready# contest
# twit_hndl_BankA Name makes my heart skip a beat! so hoping for a win tonight!# getcollegeready# contest
# twit_hndl_BankA tweeting my fingers to the bone to win this awesome BankB pack!# getcollegeready# contest
# twit_hndl_BankA.# getcollegeready# contest
# twit_hndl_BankA.# getcollegeready# contest off to college in boston my son goes soon. he would use this prize proud!
# twit_hndl_BankA twit_hndl_BankA twit_hndl_BankA# getcollegeready# contest the conveyor belt not sure how long it takes time
# twit_hndl_BankA# contest# getcollegeready and maybe a pillow
# twit_hndl_BankA# contest# getcollegeready but some of my hard earned moolah bought that kayah
# twit_hndl_BankA# contest# getcollegeready cool color for a BankB pack-the orange
# twit_hndl_BankA# contest# getcollegeready fell off of a trailer
# twit_hndl_BankA# contest# getcollegeready he did have a rebanke bad day yesterday
# twit_hndl_BankA# contest# getcollegeready if hes lucky
# twit_hndl_BankA# contest# getcollegeready i have some pity in my black heart
# twit_hndl_BankA# contest# getcollegeready maybe if hes rebanke nice ill share the tree with him
# twit_hndl_BankA# contest# getcollegeready Name hubby needs a hammock
# twit_hndl_BankA# contest# getcollegeready rebanke bad day
# twit_hndl_BankA# contest# getcollegeready seriously
# twit_hndl_BankA# contest# getcollegeready then he cracked his phone screen
# twit_hndl_BankA# contest# getcollegeready until i make him sleep in the trees lol
# twit_hndl_BankA# getcollegeready# contest Name kids need this!
# twit_hndl_BankA# getcollegeready# contest again and again!
# twit_hndl_BankA# getcollegeready# contest yes
# twit_hndl_BankA# getcollegeready# contestim ready to go!
# twit_hndl_BankA# getcollegeready# contestok she fell!!
# twit_hndl_BankA# getcollegeready# contest hope to win
# twit_hndl_BankA# getcollegeready# contest  take a limitation and turn it into an opportunity.
# twit_hndl_BankA# getcollegeready# contest  college is a refuge from hasty judgment.
# twit_hndl_BankA# getcollegeready# contest twit_hndl_BankA it is supposed to open the door to a world of opportunity
# twit_hndl_BankA# getcollegeready# contest 123
# twit_hndl_BankA# getcollegeready# contest apple
# twit_hndl_BankA# getcollegeready# contest amazing contest
# twit_hndl_BankA# getcollegeready# contest books
# twit_hndl_BankA# getcollegeready# contest BankB pack BankB pack come to mommy
# twit_hndl_BankA# getcollegeready# contest course
# twit_hndl_BankA# getcollegeready# Name Name has given me the confidence i need to fail.
# twit_hndl_BankA# getcollegeready# contest dinner
# twit_hndl_BankA# getcollegeready# contest faith
# twit_hndl_BankA# getcollegeready# contest good luck to me! and everyone else
# twit_hndl_BankA# getcollegeready# contest Name conveyor belt!
# twit_hndl_BankA# getcollegeready# contest helllllo
# twit_hndl_BankA# getcollegeready# contest ipad
# twit_hndl_BankA# getcollegeready# contest i hope i win help
# twit_hndl_BankA# getcollegeready# contest Name a student at csulb need all the help i can get
# twit_hndl_BankA# getcollegeready# contest labs
# twit_hndl_BankA# getcollegeready# contest Name please be on my side!
# twit_hndl_BankA# getcollegeready# contest lets do it!
# twit_hndl_BankA# getcollegeready# contest move that BankB pack!
# twit_hndl_BankA# getcollegeready# contest make me a winner
# twit_hndl_BankA# getcollegeready# contest never give up
# twit_hndl_BankA# getcollegeready# contest on my way to the top
# twit_hndl_BankA# getcollegeready# contest push
# twit_hndl_BankA# getcollegeready# contest qcc
# twit_hndl_BankA# getcollegeready# contest ready set fall set fall in my box
# twit_hndl_BankA# getcollegeready# contest Name
# twit_hndl_BankA# getcollegeready# contest so would like to win a BankB pack
# twit_hndl_BankA# getcollegeready# contest school is for winners make me one too!
# twit_hndl_BankA# getcollegeready# contest thanks
# twit_hndl_BankA# getcollegeready# contest very last
# twit_hndl_BankA# getcollegeready# contest who made this contest
# twit_hndl_BankA# getcollegeready# contest Name there is a will there is a way
# twit_hndl_BankA# getcollegeready# contest your game is very hard to play, it does not work, but i hope i win by tweeting here
# twit_hndl_BankA# getcollegeready# contest yes!
# twit_hndl_BankA BankA# getcollegeready and# contest
# twit_hndl_BankA# getcollegeready and# contest my tweets not working on the page
# twit_hndl_BankA# getcollegeready and# contest. ready to start i can use this
# twit_hndl_BankA# getcollegeready need to be as ready as i can be, hope this gets me closer!!
# twit_hndl_BankA# getcollegeready.# contest
# twit_hndl_BankA# getcollegeready.# contest Name hard
# twit_hndl_BankA 1 2 3 drop# getcollegeready# contest
# twit_hndl_BankA BankA Name it takes is a tweet for a chance to win prizes. if only college exams were this easy.# getcollegeready# contest
# twit_hndl_BankA arms are out and ready to catch one, i promise i wont let it fall# getcollegeready# contest
# twit_hndl_BankA at least one things free for college# getcollegeready# contest
# twit_hndl_BankA BankB  to school is so expensive# getcollegeready# contest
# twit_hndl_BankA Name conveyor belt, go, go, go!!!!# getcollegeready# contest
# twit_hndl_BankA drop me a BankB pack!!# getcollegeready.# contest
# twit_hndl_BankA for the win# getcollegeready# contest
# twit_hndl_BankA going... going# getcollegeready.# contest
# twit_hndl_BankA hoping for a win on this dreary georgia evening!# getcollegeready# contest
# twit_hndl_BankA hoping this is the tweet that makes the BankB pack drop!# getcollegeready# contest
# twit_hndl_BankA hoping this tweet conveys a BankB pack my way!# getcollegeready# contest
# twit_hndl_BankA hoping to# getcollegeready this afternoon!
# twit_hndl_BankA hopping the BankB  pac falls i so could use this foe my daughter collage is soooo expensive# getcollegeready# contest
# twit_hndl_BankA i havent won yet! my son is going away to college next week!# getcollegeready.# contest
# twit_hndl_BankA i must have that BankB pack.# getcollegeready# contest
# twit_hndl_BankA i need a new BankB pack# getcollegeready# contest
# twit_hndl_BankA i need one# getcollegeready# contest
# twit_hndl_BankA i think i won actubanke the# 9# getcollegeready# contest but its all good
# twit_hndl_BankA BankA i  m watching a conveyor belt move live on screen and loving it.# getcollegeready# contest
# twit_hndl_BankA is on clerk because they support getting an education# getcollegeready# contest
# twit_hndl_BankA Name going to be a great school year!# getcollegeready# contest
# twit_hndl_BankA just waiting for a confirmation? my BankB pack dropped, and it dropped for my sister! how do we know we won?# getcollegeready
# twit_hndl_BankA lets get this belt moving and yall sending me one of them lil bags# getcollegeready# contest
# twit_hndl_BankA move the conveyor belt. you could win a prize.# getcollegeready# contest spr. ly/ 6016beBankC2 INTERNET
# twit_hndl_BankA Name kids would be fighting over this awesome prize, thanks for the chance!# getcollegeready
# twit_hndl_BankA on# getcollegeready# contest
# twit_hndl_BankA or do you just keep tweeting new tweets here and not on the page with the conveyer belt?# getcollegeready# contest
# twit_hndl_BankA please come on drop the bag# getcollegeready# contest
# twit_hndl_BankA Name fall, please fall: )# getcollegeready# contest
# twit_hndl_BankA ready for a new year!# getcollegeready# contest
# twit_hndl_BankA send it my way# getcollegeready# contest
# twit_hndl_BankA so ready for a win, fingers crossed.# getcollegeready# contest
# twit_hndl_BankA so thankful for the chance# getcollegeready# contest
# twit_hndl_BankA stop stop# getcollegeready# contest
# twit_hndl_BankA thank you for my wonderful prize.# getcollegeready# contest INTERNET
# twit_hndl_BankA thanks for the chance to move the belt# getcollegeready# contest
# twit_hndl_BankA BankA Name conveyor belt moves. the BankB pack falls. could it be mine?# getcollegeready# contest
# twit_hndl_BankA Name time of the year makes me nostalgic for my own college years!# getcollegeready# contest
# twit_hndl_BankA Name tweet is to make the conveyor belt move move. please let me win it!# getcollegeready# contest
# twit_hndl_BankA Name a great way to start of the school year# getcollegeready# contest
# twit_hndl_BankA winning this BankB pack would be a home run!# getcollegeready# contest
# twit_hndl_BankA yall rock# getcollegeready# contest
# twit_hndl_BankA-# getcollegeready# contest love this
# twit_hndl_BankA-# getcollegeready# contest how will we know if it falls
# twit_hndl_BankA: ahhh so close# getcollegeready# contest
# twit_hndl_BankA: maybe just maybe i will win# getcollegeready# contest
# twit_hndl_BankA: )# getcollegeready# contest
# twit_hndl_BankA!!# getcollegeready# contest
# twit_hndl_BankA!!!# getcollegeready# contest
# twit_hndl_BankA!!!!!!!!!!!!!!!!! ahhhhhhhhhhhh!!!!!!!!!!!!!!!# getcollegeready# contest
# twit_hndl_BankA?? BankAfar-goat# getcollegeready# contest
# twit_hndl_BankA?? why not?# getcollegeready# contest
# twit_hndl_BankA???? all it takes is a tweet for a chance to win prizes. if only college exams were this easy.??# getcollegeready# contest# winner
# twit_hndl_BankA???? for real  gimme that BankB pack, pls.# getcollegeready# contest
# twit_hndl_BankA???? for real, please gimme that BankB pack.# getcollegeready# contest# BankB packfallnow# fallingBankB pack# warningfallingBankB packs??
# twit_hndl_BankA???? i have the power to try & win that# BankB pack.# getcollegeready# contest# BankB pack# contestalert# BankA # winner# thankyou
# twit_hndl_BankA???? i just might win a prize w/ this tweet!???? wish me luck.??# getcollegeready# contest# contestalert# thanksBankA # winner
# twit_hndl_BankA???? i just virtubanke moved a# BankB pack! i will;)win whats inside inside.# getcollegeready# contest# determined# determination# winner
# twit_hndl_BankA???? i must have that# BankB pack full of prizes, please!!# getcollegeready# contest# fallingBankB pack# thankyou# happythursday????
# twit_hndl_BankA???? i must have that BankB pack full of prizes, please.# getcollegeready# contest# contestalert# BankA # fallingBankB pack??
# twit_hndl_BankA???? i need to have that BankB pack full full of prizes, pls.# getcollegeready# contest# pleasepickme# BankA # contestalert# thankyou
# twit_hndl_BankA???? i want to start# college w/ sweet prizes. make that# BankB pack# fall!?? (# cheering )??# getcollegeready# contest# fallingBankB pack
# twit_hndl_BankA???? i want to start college with sweet prizes, please! make that# BankB pack fall!# getcollegeready# contest# contestalert# thanks??
# twit_hndl_BankA???? Name going to start college off right with that sweet# BankB pack, bc its# falling.??# getcollegeready# contest# fallingBankB pack
# twit_hndl_BankA???? Name ready for college, & Name ready to try & win that# BankB pack! fall, fall, fall!# getcollegeready# contest# fallingBankB pack
# twit_hndl_BankA???? Name using my willpower, and my tweet, to try and win that BankB pack.# getcollegeready# contest# thanks# college# contestalert
# twit_hndl_BankA???? the conveyor belt moves! the# BankB pack falls! could it be mine?!# getcollegeready# contest# pleasefall# pleasepickme# thanks
# twit_hndl_BankA???? this could be my greatest tweet ever. please?? make the# BankB pack# fall.# getcollegeready# contest??# warningfallingBankB packs??
# twit_hndl_BankA???? this tweet is to make the# conveyor# belt move. please let me win it!??# getcollegeready# contest# thanksBankA # college
# twit_hndl_BankA???? whoa! i just moved that BankB pack.???? i hope i make it fall off & win.# getcollegeready# contest# contestalert# BankA
# twit_hndl_BankA???? whoa!?? i just moved that BankB pack.?? i hope i make it fall off and win.????# getcollegeready# contest# pleasefall# pleasepickme
# twit_hndl_BankA???? whoa. i just moved that# BankB pack. i hope i make it fall off & win.????# getcollegeready# contest# BankA # pleasefall????
# twit_hndl_BankA?????? i just might win a prize with this tweet.?? wish me luck.??# getcollegeready# contest# pleasefall# fallingBankB pack# BankA
# twit_hndl_BankA?????? i just virtubanke moved a BankB pack. i might even win whats inside.# getcollegeready# contest
# twit_hndl_BankA?????? Name going to start college off right with that sweet BankB pack.# getcollegeready# contest??????
# twit_hndl_BankA?????? Name ready for# college, & Name very ready to try & win that# BankB pack!# getcollegeready# contest# contestalert# thankyou??????
# twit_hndl_BankA?????? Name using my willpower, & my tweet, to try & win that BankB pack.# getcollegeready# contest# contestalert# thanksBankA
# twit_hndl_BankA???????? i just might win a prize with this tweet. wish me luck.# getcollegeready# contest
# twit_hndl_BankA???????? i must have that BankB pack full of prizes.# getcollegeready# contest
# twit_hndl_BankA??????# getcollegeready# contest
# twit_hndl_BankA???? i don  t know what  s more exBankCng  college, homework, or trying to win these prizes.??# getcollegeready# contest# BankB toschool
# twit_hndl_BankA???? i just might win! join me in trying to move a conveyor belt of BankB packs for a chance to win prizes.# getcollegeready# contest
# twit_hndl_BankA???? Name using my willpower & my tweet, to try & win that BankB pack.# getcollegeready# contest# pleasefall# pleasepickme# thanks
# twit_hndl_BankA???? Name could be my greatest tweet! please make the BankB pack fall.# getcollegeready# contest# contestalert# pleasefall# thanks
# twit_hndl_BankA?? i must have that BankB pack. i must have that BankB pack, pls.# getcollegeready# contest# contestalert# BankA # thanks# college
# twit_hndl_BankA?? i want to win whats in that BankB pack. Name ready for college, and ready to try and win that BankB pack!# getcollegeready# contest
# twit_hndl_BankA?? movingtheconveyorbelt??# getcollegeready# contest
# twit_hndl_BankA?? Name conveyor belt moves. the# BankB pack falls. could it be mine? yes!# getcollegeready# contest??# contestalert# thanksBankA
# twit_hndl_BankA?? Name could be my greatest tweet ever.?? please make the BankB pack fall????????.# getcollegeready# contest??# contestalert# BankA
# twit_hndl_BankA d rather be smart than a movie star.# getcollegeready.# contest spr. ly/ 6010becjw
# twit_hndl_BankA pack 2 college was pretty clever# getcollegeready# contest
# twit_hndl_BankA# getcollegeready# contest
# twit_hndl_BankA twit_hndl congrats lucky winner!# getcollegeready# contest
# twit_hndl_BankA twit_hndl# contest# getcollegeready
# twit_hndl_BankA twit_hndl yay!# getcollegeready# contest
# twit_hndl_BankA twit_hndl congratulations!# getcollegeready# contest
# twit_hndl_BankA twit_hndl congrats lucky winner# getcollegeready# contest
# twit_hndl_BankA twit_hndl congrats!# getcollegeready# contest
# twit_hndl_BankA twit_hndl congrats! Name just a little jealous!??# getcollegeready# contest
# twit_hndl_BankA twit_hndl Name you! congrats!# getcollegeready# contest
# twit_hndl_BankA twit_hndl# getcollegeready# contest
# twit_hndl_BankA twit_hndl yay!# getcollegeready
# twit_hndl_BankA twit_hndl congrats!!!# getcollegeready# contest
# twit_hndl_BankA twit_hndl you should do this# getcollegeready# contest
# twit_hndl_BankA twit_hndl good job!# getcollegeready# contest
# twit_hndl_BankA twit_hndl Name moving moving# getcollegeready# contest
# twit_hndl_BankA twit_hndl Name soooo ready# getcollegeready# contest
# twit_hndl_BankA twit_hndl congratulations!!!# getcollegeready# contest
# twit_hndl_BankA twit_hndl is a winner, right?# getcollegeready# contest
# twit_hndl_BankA twit_hndl lucky winner congrats!# getcollegeready# contest
# twit_hndl_BankA twit_hndl congrats# getcollegeready# contest
# twit_hndl_BankA twit_hndl: twit_hndl_BankA# getcollegeready# contest pleasssse
# twit_hndl_BankA twit_hndl# getcollegeready# contest BankB pack! BankB pack! BankB pack!
# twit_hndl_BankA twit_hndl good job!!!# getcollegeready# contest
# twit_hndl_BankA twit_hndl congrats!!!!# getcollegeready# contest
# twit_hndl_BankA twit_hndl lucky winner!# getcollegeready# contest Name
# twit_hndl_BankA twit_hndl so lucky congrats Name!# getcollegeready# contest
# twit_hndl_BankA twit_hndl & i could carry around a duck in the picnic basket# getcollegeready# contest
# twit_hndl_BankA twit_hndl now we wait# getcollegeready# contest
# twit_hndl_BankA twit_hndl quite stressful. cmon BankB pack BankB pack cmonnnn.# getcollegeready# contest
# twit_hndl_BankA twit_hndl very nice congrats!# getcollegeready# contest
# twit_hndl_BankA twit_hndl Name you congrats!# getcollegeready# contest
# twit_hndl_BankA twit_hndl_BankA# getcollegeready# contest twit_hndl_BankA i am super tired. send me the BankB pack please
# twit_hndl_BankA twit_hndl_BankA twit_hndl_BankA twit_hndl_BankA# getcollegeready# contest the conveyor belt think of me please
# twit_hndl_BankA twit_hndl_BankA twit_hndl_BankA# getcollegeready# contest the conveyor belt thanks for the chance
# twit_hndl_BankA twit_hndl_BankA# getcollegeready# contest
# twit_hndl_BankA twit_hndl_BankA move the BankB pack along the conveyor belt# getcollegeready# contest
# twit_hndl_BankA twit_hndl_BankA Name. move the conveyor belt. you could win a prize.# getcollegeready# contest
# twit_hndl_BankA * * caution * * this is a# falling# BankB pack# zone!??# warning# falling# BankB packs# ahead??# getcollegeready# contest# contestalert
# twit_hndl_BankA * sings dora BankB pack song song *# getcollegeready# contest
# twit_hndl_BankA\ move the BankB pack along the conveyor belt# getcollegeready# contest
# twit_hndl_BankA# contest move the BankB pack along the conveyor belt# getcollegeready
# twit_hndl_BankA# contest# getcollegeready
# twit_hndl_BankA# contest# getcollegeready# please# bestbankever
# twit_hndl_BankA# contest# getcollegeready and then there were 4
# twit_hndl_BankA# contest# getcollegeready BankB packs BankB packs!!
# twit_hndl_BankA# contest# getcollegeready cmon lets win
# twit_hndl_BankA# contest# getcollegeready come ooonnn!!!!!!
# twit_hndl_BankA# contest# getcollegeready drop drop it down
# twit_hndl_BankA# contest# getcollegeready give me a BankB pack!
# twit_hndl_BankA# contest# getcollegeready go packs
# twit_hndl_BankA# contest# getcollegeready great prize prize!
# twit_hndl_BankA# contest# getcollegeready it is awesome to be debt-free graduating out of college!:)
# twit_hndl_BankA# contest# getcollegeready let it fall
# twit_hndl_BankA# contest# getcollegeready love love 2 win
# twit_hndl_BankA# contest# getcollegeready need for school
# twit_hndl_BankA# contest# getcollegeready please please please
# twit_hndl_BankA# contest# getcollegeready so colse to it
# twit_hndl_BankA# getcollegeready# contest move conveyor belt along and drop in my timelinrke
# twit_hndl_BankA# getcollegeready# contest wow
# twit_hndl_BankA# getcollegeready# contest# getcollegeready# contest v
# twit_hndl_BankA# getcollegeready# contest anticipation
# twit_hndl_BankA# getcollegeready# contest a lot of people want a shortcut.
# twit_hndl_BankA# getcollegeready# contest BankB pack fall off conveyor belt to me
# twit_hndl_BankA# getcollegeready# contest BankB  pack attack
# twit_hndl_BankA# getcollegeready# contest chemistry tough as????????
# twit_hndl_BankA# getcollegeready# contest can we when this time!??
# twit_hndl_BankA# getcollegeready# contest drop# getcollegeready# contest
# twit_hndl_BankA# getcollegeready# contest eventubanke fall into the box
# twit_hndl_BankA# getcollegeready# contest final prize
# twit_hndl_BankA# getcollegeready# contest gee whiz
# twit_hndl_BankA# getcollegeready# contest had a
# twit_hndl_BankA# getcollegeready# contest i dont rebanke know if Name hash tagging this correct
# twit_hndl_BankA# getcollegeready# contest it comes
# twit_hndl_BankA# getcollegeready# contest Name asking
# twit_hndl_BankA# getcollegeready# contest i am ready to win a BankB pack
# twit_hndl_BankA# getcollegeready# contest keep it up yall
# twit_hndl_BankA# getcollegeready# contest lets win!
# twit_hndl_BankA# getcollegeready# contest last one folks
# twit_hndl_BankA# getcollegeready# contest lets move the BankB pack
# twit_hndl_BankA# getcollegeready# contest move the conveyor belt
# twit_hndl_BankA# getcollegeready# contest me
# twit_hndl_BankA# getcollegeready# contest need the supplles
# twit_hndl_BankA# getcollegeready# contest nice to chill with
# twit_hndl_BankA# getcollegeready# contest or do they
# twit_hndl_BankA# getcollegeready# contest peace out
# twit_hndl_BankA# getcollegeready# contest qwkk
# twit_hndl_BankA# getcollegeready# contest time is almost up
# twit_hndl_BankA# getcollegeready# contest Name an opportunity and turn it into an adventure by dreaming big!
# twit_hndl_BankA# getcollegeready# contest until it drops and boom i get a message
# twit_hndl_BankA# getcollegeready# contest very soon
# twit_hndl_BankA# getcollegeready# contest would be nice if i win
# twit_hndl_BankA# getcollegeready# contest Name, i am sailing down this belt and on my way to twit_hndl
# twit_hndl_BankA# getcollegeready# contest ya that
# twit_hndl_BankA# getcollegeready# contest you can steer yourself any direction you choose. youre on your own
# twit_hndl_BankA# getcollegeready# contestand it went
# twit_hndl_BankA# getcollegeready# college i need a new BankB pack
# twit_hndl_BankA# getcollegeready# conference jsks
# twit_hndl_BankA BankA# getcollegeready# contest
# twit_hndl_BankA# getcollegeready# contest jjj
# twit_hndl_BankA# getcollegeready# contest eeee
# twit_hndl_BankA# getcollegeready# contest$ 500 in quarters?!? it all spends the same!!
# twit_hndl_BankA# getcollegeready# contest 11
# twit_hndl_BankA# getcollegeready# contest 2 daughters in college... this would be great!
# twit_hndl_BankA# getcollegeready# contest almost school time
# twit_hndl_BankA# getcollegeready# contest almost there
# twit_hndl_BankA# getcollegeready# contest amazing contest. thank you and i hope i win!
# twit_hndl_BankA# getcollegeready# contest BankB  to school is easier with a tablet!
# twit_hndl_BankA# getcollegeready# contest come on lets win
# twit_hndl_BankA# getcollegeready# contest Name to the winners! great contest BankA!
# twit_hndl_BankA# getcollegeready# contest Name you forget about me?
# twit_hndl_BankA# getcollegeready# contest fff
# twit_hndl_BankA# getcollegeready# contest gosh i want one of these
# twit_hndl_BankA# getcollegeready# contest Name going!
# twit_hndl_BankA# getcollegeready# contest im readyyy
# twit_hndl_BankA# getcollegeready# contest i am not sure whether you get my entries or not Name help
# twit_hndl_BankA# getcollegeready# contest just waiting for that notification!!
# twit_hndl_BankA# getcollegeready# contest lets get a winner:)
# twit_hndl_BankA# getcollegeready# contest moving the conveyor belt
# twit_hndl_BankA# getcollegeready# contest Name! guess i missed out this time. thanks for the fun:)
# twit_hndl_BankA# getcollegeready# contest Name!
# twit_hndl_BankA# getcollegeready# contest need a new one
# twit_hndl_BankA# getcollegeready# contest no time to eat
# twit_hndl_BankA# getcollegeready# contest Name this!!!!# crazyteens?? INTERNET
# twit_hndl_BankA# getcollegeready# contest Name i want to win the smart watch
# twit_hndl_BankA# getcollegeready# contest probably going to twitter jail soon!!:)
# twit_hndl_BankA# getcollegeready# contest super fun contest fun contest
# twit_hndl_BankA# getcollegeready# contest super prizes. super fun. hope you do it again sometime BankA:)
# twit_hndl_BankA# getcollegeready# contest there it goes
# twit_hndl_BankA# getcollegeready# contest Name you for the contest. it was fun. i hope everyone enjoyed it and the winners enjoy the prizes
# twit_hndl_BankA# getcollegeready# contest vd
# twit_hndl_BankA# getcollegeready# contest will i win it?
# twit_hndl_BankA# getcollegeready# contest,,,,,,,,,,,,,
# twit_hndl_BankA# getcollegeready# contest:)
# twit_hndl_BankA# getcollegeready# contest!
# twit_hndl_BankA# getcollegeready# contest!!
# twit_hndl_BankA# getcollegeready# contest!!!!!!!
# twit_hndl_BankA# getcollegeready# contest???????? its a BankB pack party????????
# twit_hndl_BankA# getcollegeready# contest????
# twit_hndl_BankA# getcollegeready# contest..
# twit_hndl_BankA# getcollegeready# contest ): &::
# twit_hndl_BankA# getcollegeready# contest twit_hndl join now, its fun! good luck!
# twit_hndl_BankA# getcollegeready# contest twit_hndl_BankA
# twit_hndl_BankA# getcollegeready# contest twit_hndl_BankA a college degree is the key to realizing the american dream
# twit_hndl_BankA# getcollegeready# contest & mnn
# twit_hndl_BankA# getcollegeready# contest# contest
# twit_hndl_BankA# getcollegeready# contest# forelandplace.. although i didnt win a BankB pack, thanks for having this nice promotion.
# twit_hndl_BankA# getcollegeready# contest# getcollegeready# contest# getcollegeready# contest
# twit_hndl_BankA# getcollegeready# contest# lovethisbank
# twit_hndl_BankA# getcollegeready# contest < 3 < 3
# twit_hndl_BankA# getcollegeready# contest =)
# twit_hndl_BankA# getcollegeready# contest??
# twit_hndl_BankA# getcollegeready# contest$: &/
# twit_hndl_BankA# getcollegeready# contest 01
# twit_hndl_BankA# getcollegeready# contest 1
# twit_hndl_BankA# getcollegeready# contest 111
# twit_hndl_BankA# getcollegeready# contest 1234d
# twit_hndl_BankA# getcollegeready# contest 13
# twit_hndl_BankA# getcollegeready# contest 15
# twit_hndl_BankA# getcollegeready# contest 16
# twit_hndl_BankA# getcollegeready# contest 17
# twit_hndl_BankA# getcollegeready# contest 19
# twit_hndl_BankA# getcollegeready# contest 2
# twit_hndl_BankA# getcollegeready# contest 20
# twit_hndl_BankA# getcollegeready# contest 21
# twit_hndl_BankA# getcollegeready# contest 22
# twit_hndl_BankA# getcollegeready# contest 23
# twit_hndl_BankA# getcollegeready# contest 24
# twit_hndl_BankA# getcollegeready# contest 25
# twit_hndl_BankA# getcollegeready# contest 26
# twit_hndl_BankA# getcollegeready# contest 27
# twit_hndl_BankA# getcollegeready# contest 28
# twit_hndl_BankA# getcollegeready# contest 29
# twit_hndl_BankA# getcollegeready# contest 3
# twit_hndl_BankA# getcollegeready# contest 3 kids need BankB packs
# twit_hndl_BankA# getcollegeready# contest 30
# twit_hndl_BankA# getcollegeready# contest 31
# twit_hndl_BankA# getcollegeready# contest 32
# twit_hndl_BankA# getcollegeready# contest 33
# twit_hndl_BankA# getcollegeready# contest 34
# twit_hndl_BankA# getcollegeready# contest 35
# twit_hndl_BankA# getcollegeready# contest 36
# twit_hndl_BankA# getcollegeready# contest 37
# twit_hndl_BankA# getcollegeready# contest 38
# twit_hndl_BankA# getcollegeready# contest 39
# twit_hndl_BankA# getcollegeready# contest 3kids in school this year.. supplies needed
# twit_hndl_BankA# getcollegeready# contest 4
# twit_hndl_BankA# getcollegeready# contest 40
# twit_hndl_BankA# getcollegeready# contest 41
# twit_hndl_BankA# getcollegeready# contest 42
# twit_hndl_BankA# getcollegeready# contest 43
# twit_hndl_BankA# getcollegeready# contest 44
# twit_hndl_BankA# getcollegeready# contest 45
# twit_hndl_BankA# getcollegeready# contest 456
# twit_hndl_BankA# getcollegeready# contest 46
# twit_hndl_BankA# getcollegeready# contest 47
# twit_hndl_BankA# getcollegeready# contest 48
# twit_hndl_BankA# getcollegeready# contest 49
# twit_hndl_BankA# getcollegeready# contest 5
# twit_hndl_BankA# getcollegeready# contest 50
# twit_hndl_BankA# getcollegeready# contest 51
# twit_hndl_BankA# getcollegeready# contest 52
# twit_hndl_BankA# getcollegeready# contest 53
# twit_hndl_BankA# getcollegeready# contest 54
# twit_hndl_BankA# getcollegeready# contest 55
# twit_hndl_BankA# getcollegeready# contest 56
# twit_hndl_BankA# getcollegeready# contest 57
# twit_hndl_BankA# getcollegeready# contest 58
# twit_hndl_BankA# getcollegeready# contest 59
# twit_hndl_BankA# getcollegeready# contest 6
# twit_hndl_BankA# getcollegeready# contest 60
# twit_hndl_BankA# getcollegeready# contest 61
# twit_hndl_BankA# getcollegeready# contest 62
# twit_hndl_BankA# getcollegeready# contest 63
# twit_hndl_BankA# getcollegeready# contest 64
# twit_hndl_BankA# getcollegeready# contest 65
# twit_hndl_BankA# getcollegeready# contest 66
# twit_hndl_BankA# getcollegeready# contest 67
# twit_hndl_BankA# getcollegeready# contest 68
# twit_hndl_BankA# getcollegeready# contest 69
# twit_hndl_BankA# getcollegeready# contest 7
# twit_hndl_BankA# getcollegeready# contest 70
# twit_hndl_BankA# getcollegeready# contest 71
# twit_hndl_BankA# getcollegeready# contest 72
# twit_hndl_BankA# getcollegeready# contest 73
# twit_hndl_BankA# getcollegeready# contest 74
# twit_hndl_BankA# getcollegeready# contest 75
# twit_hndl_BankA# getcollegeready# contest 76
# twit_hndl_BankA# getcollegeready# contest 77
# twit_hndl_BankA# getcollegeready# contest 78
# twit_hndl_BankA# getcollegeready# contest 79
# twit_hndl_BankA# getcollegeready# contest 81
# twit_hndl_BankA# getcollegeready# contest 82
# twit_hndl_BankA# getcollegeready# contest 83
# twit_hndl_BankA# getcollegeready# contest a
# twit_hndl_BankA# getcollegeready# contest a tablet would be super! would love it! hope i win! drop! drop! winner? winner? drop!:)
# twit_hndl_BankA# getcollegeready# contest aa
# twit_hndl_BankA# getcollegeready# contest about to fall# getcollegeready# contest
# twit_hndl_BankA# getcollegeready# contest accccc
# twit_hndl_BankA# getcollegeready# contest ad
# twit_hndl_BankA# getcollegeready# contest ae
# twit_hndl_BankA# getcollegeready# contest af
# twit_hndl_BankA# getcollegeready# contest ag
# twit_hndl_BankA# getcollegeready# contest ah
# twit_hndl_BankA# getcollegeready# contest Name almost
# twit_hndl_BankA# getcollegeready# contest ai
# twit_hndl_BankA# getcollegeready# contest ajkknk
# twit_hndl_BankA# getcollegeready# contest almost fallen
# twit_hndl_BankA# getcollegeready# contest allllxnd
# twit_hndl_BankA# getcollegeready# contest almost
# twit_hndl_BankA# getcollegeready# contest always be kind, someone is watching
# twit_hndl_BankA# getcollegeready# contest anannna
# twit_hndl_BankA# getcollegeready# contest apartment, classes, groceries, and bills.
# twit_hndl_BankA# getcollegeready# contest aqqq
# twit_hndl_BankA# getcollegeready# contest ar
# twit_hndl_BankA# getcollegeready# contest are you ready 4 college?
# twit_hndl_BankA# getcollegeready# contest as
# twit_hndl_BankA# getcollegeready# contest at
# twit_hndl_BankA# getcollegeready# contest auuuu
# twit_hndl_BankA# getcollegeready# contest awesome!!!
# twit_hndl_BankA# getcollegeready# contest b
# twit_hndl_BankA# getcollegeready# contest balloons
# twit_hndl_BankA# getcollegeready# contest BankB  to school time
# twit_hndl_BankA# getcollegeready# contest BankB pack BankB pack
# twit_hndl_BankA# getcollegeready# contest BankB pack 18 Name be great to win!
# twit_hndl_BankA# getcollegeready# contest BankB pack please
# twit_hndl_BankA# getcollegeready# contest BankB packs are whats up!
# twit_hndl_BankA# getcollegeready# contest Name a good student
# twit_hndl_BankA# getcollegeready# contest best of luck all# getcollegeready# contest
# twit_hndl_BankA# getcollegeready# contest best bet on me
# twit_hndl_BankA# getcollegeready# contest Name brave
# twit_hndl_BankA# getcollegeready# contest big tease
# twit_hndl_BankA# getcollegeready# contest big winner
# twit_hndl_BankA# getcollegeready# contest blame kyle p
# twit_hndl_BankA# getcollegeready# contest books information knowledge = wealth
# twit_hndl_BankA# getcollegeready# contest bring it this way ill share with my nieces
# twit_hndl_BankA# getcollegeready# contest Name apples for your teacher
# twit_hndl_BankA# getcollegeready# contest but i need the BankB pack too
# twit_hndl_BankA# getcollegeready# contest build build your home on a solid foundation
# twit_hndl_BankA# getcollegeready# contest c
# twit_hndl_BankA# getcollegeready# contest can ya feel it
# twit_hndl_BankA# getcollegeready# contest can i win once more?
# twit_hndl_BankA# getcollegeready# Name cause Name happy
# twit_hndl_BankA# getcollegeready# contest cheers
# twit_hndl_BankA# getcollegeready# contest cheer me up
# twit_hndl_BankA# getcollegeready# contest clap along if youre happy
# twit_hndl_BankA# getcollegeready# contest cmon BankB pack. fall so we can bring our small animals around campus. twit_hndl
# twit_hndl_BankA# getcollegeready# contest come on
# twit_hndl_BankA# getcollegeready# contest Name down the days
# twit_hndl_BankA# getcollegeready# contest come to momma!
# twit_hndl_BankA# getcollegeready# contest Name student at Name! twit_hndl_BankA is a way of life here!
# twit_hndl_BankA# getcollegeready# contest come home to mommy INTERNET
# twit_hndl_BankA# getcollegeready# contest Name rebanke use a BankB pack
# twit_hndl_BankA# getcollegeready# contest crossing my fingers. hoping for a win
# twit_hndl_BankA# getcollegeready# contest d
# twit_hndl_BankA# getcollegeready# contest ddd
# twit_hndl_BankA# getcollegeready# contest Name dong right timing
# twit_hndl_BankA# getcollegeready# contest djkdkz
# twit_hndl_BankA# getcollegeready# contest does it ever fall
# twit_hndl_BankA# getcollegeready# contest Name enable bullies. be a leader
# twit_hndl_BankA# getcollegeready# contest do u dm us?
# twit_hndl_BankA# getcollegeready# contest Name forget about me!!
# twit_hndl_BankA# getcollegeready# contest dont put off tomorrow what you can do today college ready
# twit_hndl_BankA# getcollegeready# contest Name worry be happy
# twit_hndl_BankA# getcollegeready# contest Name drop
# twit_hndl_BankA# getcollegeready# contest drop n my box please
# twit_hndl_BankA# getcollegeready# contest Name drop drop
# twit_hndl_BankA# getcollegeready# contest e
# twit_hndl_BankA# getcollegeready# contest eeeeeeeeeeeeeee
# twit_hndl_BankA# getcollegeready# contest eteawe
# twit_hndl_BankA# getcollegeready# contest Name for the kids
# twit_hndl_BankA# getcollegeready# contest excited for the new school year
# twit_hndl_BankA# getcollegeready# contest exercise exercise your mind it pays off
# twit_hndl_BankA# getcollegeready# contest f
# twit_hndl_BankA# getcollegeready# contest fall fall fall fall fall
# twit_hndl_BankA# getcollegeready# contest fall
# twit_hndl_BankA# getcollegeready# contest fall like leaves INTERNET
# twit_hndl_BankA# getcollegeready# contest fddfd
# twit_hndl_BankA# getcollegeready# contest first Name is gonna be mine
# twit_hndl_BankA# getcollegeready# contest fingers
# twit_hndl_BankA# getcollegeready# contest Name paunful
# twit_hndl_BankA# getcollegeready# contest final prize!! crossing my fingers and toes!!! have been in twitter jail jail:(( i rebanke want that BankB pack!
# twit_hndl_BankA# getcollegeready# contest find your yes INTERNET
# twit_hndl_BankA# getcollegeready# contest friends, just ignore me
# twit_hndl_BankA# getcollegeready# contest fsaere
# twit_hndl_BankA# getcollegeready# contest fun
# twit_hndl_BankA# getcollegeready# contest fun contest!
# twit_hndl_BankA# getcollegeready# contest Name day. i hope everyone enjoys their prizes. i hope BankA does this again!
# twit_hndl_BankA# getcollegeready# contest g
# twit_hndl_BankA# getcollegeready# contest get that BankB pack moving!!
# twit_hndl_BankA# getcollegeready# contest get ready to dance
# twit_hndl_BankA# getcollegeready# contest ghher
# twit_hndl_BankA# getcollegeready# contest give it away
# twit_hndl_BankA# getcollegeready# contest give me that BankB BankB  please
# twit_hndl_BankA# getcollegeready# contest give me courage
# twit_hndl_BankA# getcollegeready# contest go go go
# twit_hndl_BankA# getcollegeready# contest good times
# twit_hndl_BankA# getcollegeready# contest good luck everyone vv
# twit_hndl_BankA# getcollegeready# contest Name conveyor belt go! i want the goods!
# twit_hndl_BankA# getcollegeready# contest Name debate, whats up Name?
# twit_hndl_BankA# getcollegeready# contest great prize
# twit_hndl_BankA# getcollegeready# contest great
# twit_hndl_BankA# getcollegeready# contest great prizes!
# twit_hndl_BankA# getcollegeready# contest gsfsf
# twit_hndl_BankA# getcollegeready# contest h
# twit_hndl_BankA# getcollegeready# contest h6adfga
# twit_hndl_BankA# getcollegeready# contest have i won?
# twit_hndl_BankA# getcollegeready# contest had to make a new twitter because i was blowing up everyones tl
# twit_hndl_BankA# getcollegeready# contest hard decision
# twit_hndl_BankA# getcollegeready# contest happy birthday
# twit_hndl_BankA# getcollegeready# contest happy days are here again!
# twit_hndl_BankA# getcollegeready# contest hddjsk
# twit_hndl_BankA# getcollegeready# contest here it comes
# twit_hndl_BankA# getcollegeready# contest hey twit_hndl come ck this out
# twit_hndl_BankA# getcollegeready# contest heres to BankA move along!
# twit_hndl_BankA# getcollegeready# contest hfweruiii
# twit_hndl_BankA# getcollegeready# contest high fives
# twit_hndl_BankA# getcollegeready# contest hook me up
# twit_hndl_BankA# getcollegeready# contest hope i win
# twit_hndl_BankA# getcollegeready# contest hoping to win this thig
# twit_hndl_BankA# getcollegeready# contest hope i win this BankB pack with an awesome tablet. contest is nearing an end. winnnnnnnnnnnnnner!!!
# twit_hndl_BankA# getcollegeready# contest hreart
# twit_hndl_BankA# getcollegeready# contest hskids
# twit_hndl_BankA# getcollegeready# contest htrs r
# twit_hndl_BankA# getcollegeready# contest hurry before twitter blocks me again
# twit_hndl_BankA# getcollegeready# contest huertwaq
# twit_hndl_BankA# getcollegeready# Name Name up school; much needed mama time???? INTERNET
# twit_hndl_BankA# getcollegeready# contest hyrey 5 r
# twit_hndl_BankA# getcollegeready# contest i
# twit_hndl_BankA BankA# getcollegeready# contest i dont want to look at belt or i may lose a tweet
# twit_hndl_BankA# getcollegeready# contest i see movement!
# twit_hndl_BankA# getcollegeready# contest i need a BankB pack
# twit_hndl_BankA# getcollegeready# contest i hope i win!
# twit_hndl_BankA# getcollegeready# contest i am ready to win at least one bag and won it love it
# twit_hndl_BankA# getcollegeready# contest i dont want to brag
# twit_hndl_BankA# getcollegeready# contest i hope u gave it youre all
# twit_hndl_BankA BankA# getcollegeready# contest Name quitting after this one booo
# twit_hndl_BankA# getcollegeready# contest Name almost with my undergraduate studies
# twit_hndl_BankA# getcollegeready# contest Name love to have that prize of the final BankB pack
# twit_hndl_BankA# getcollegeready# contest Name ready
# twit_hndl_BankA# getcollegeready# contest Name builds character
# twit_hndl_BankA# getcollegeready# contest im so ready
# twit_hndl_BankA# getcollegeready# contest in just a minute
# twit_hndl_BankA# getcollegeready# contest Name it to win it!
# twit_hndl_BankA# getcollegeready# contest in Name we trust
# twit_hndl_BankA# getcollegeready# contest Name the conveyor belt made in the usa, please move the conveyor belt INTERNET
# twit_hndl_BankA# getcollegeready# contest is this worth it?
# twit_hndl_BankA# getcollegeready# contest is it to late:(
# twit_hndl_BankA# getcollegeready# contest is the conveyor belt moving? twit_hndl_BankA
# twit_hndl_BankA# getcollegeready# contest it is sent
# twit_hndl_BankA# getcollegeready# contest it is coming
# twit_hndl_BankA# getcollegeready# contest Name sure does take a while to push this BankB pack off.
# twit_hndl_BankA# getcollegeready# contest its august 6, tgit
# twit_hndl_BankA# getcollegeready# contest Name fell in and i saw confetti!! did i win??
# twit_hndl_BankA# getcollegeready# contest j
# twit_hndl_BankA# getcollegeready# contest jerwe
# twit_hndl_BankA# getcollegeready# contest jhjdere
# twit_hndl_BankA# getcollegeready# contest jjjjjjjjjjjjjjjjjjjjjjjjjjjjj
# twit_hndl_BankA# getcollegeready# contest jksksl
# twit_hndl_BankA# getcollegeready# contest joy
# twit_hndl_BankA# getcollegeready# contest jrawes
# twit_hndl_BankA# getcollegeready# contest js
# twit_hndl_BankA# getcollegeready# contest jtrrweaq
# twit_hndl_BankA BankA# getcollegeready# contest just say my name already, i winnnn
# twit_hndl_BankA# getcollegeready# contest just a bit moree
# twit_hndl_BankA# getcollegeready# contest k
# twit_hndl_BankA# getcollegeready# contest keep tweeting
# twit_hndl_BankA# getcollegeready# contest keep trying
# twit_hndl_BankA# getcollegeready# contest Name moving!
# twit_hndl_BankA# getcollegeready# contest kids are excited
# twit_hndl_BankA# getcollegeready# contest kkkkklaoal
# twit_hndl_BankA# getcollegeready# contest knowlegde is power
# twit_hndl_BankA# getcollegeready# contest large and in charge
# twit_hndl_BankA# getcollegeready# contest last chance for me
# twit_hndl_BankA# getcollegeready# contest Name BankB pack!
# twit_hndl_BankA# getcollegeready# contest lets Name team
# twit_hndl_BankA# getcollegeready# contest lets win this pickme!
# twit_hndl_BankA# getcollegeready# contest Name go
# twit_hndl_BankA# getcollegeready# contest lets get this!
# twit_hndl_BankA# getcollegeready# contest liky
# twit_hndl_BankA# getcollegeready# contest Name how it is filled up
# twit_hndl_BankA# getcollegeready# contest lift lift yourself to higher goals
# twit_hndl_BankA# getcollegeready# contest llllkhu
# twit_hndl_BankA# getcollegeready# contest love it
# twit_hndl_BankA# getcollegeready# contest love the prize
# twit_hndl_BankA# getcollegeready# contest long summer day summer day:)
# twit_hndl_BankA# getcollegeready# contest Name friends
# twit_hndl_BankA# getcollegeready# contest mary had a little lamb
# twit_hndl_BankA# getcollegeready# contest me me me!!!!!! please
# twit_hndl_BankA# getcollegeready# contest memories, make some
# twit_hndl_BankA# getcollegeready# contest move my pack
# twit_hndl_BankA# getcollegeready# contest move that belt
# twit_hndl_BankA# getcollegeready# Name move the bagpack along the conveyor belt
# twit_hndl_BankA# getcollegeready# contest more BankB packs please keep it moving
# twit_hndl_BankA# getcollegeready# contest move that BankB pack along!
# twit_hndl_BankA# getcollegeready# Name move the BankB pack to the front of the class
# twit_hndl_BankA# getcollegeready# contest move move that belt,
# twit_hndl_BankA# getcollegeready# contest Name interest has been peaked????
# twit_hndl_BankA# getcollegeready# contest my BankB  is crushing on your BankA BankB pack
# twit_hndl_BankA# getcollegeready# contest Name daughter in college needs this
# twit_hndl_BankA# getcollegeready# contest my kids are ready
# twit_hndl_BankA# getcollegeready# contest need not want BankB pack
# twit_hndl_BankA# getcollegeready# contest need a BankB pack for the win!!
# twit_hndl_BankA# getcollegeready# contest need one of these BankB packs!
# twit_hndl_BankA# getcollegeready# contest nfl on its way
# twit_hndl_BankA# getcollegeready# contest nice prize
# twit_hndl_BankA# getcollegeready# contest nice try
# twit_hndl_BankA# getcollegeready# contest nice BankB pack!
# twit_hndl_BankA# getcollegeready# contest now is the time
# ...
# wakeup_morons: BankA  Name tweet is to make the conveyor belt move move. please let me win it!# getcollegeready# co  INTERNET
# want it now Name Name twit_hndl_BankA# getcollegeready# contest
# want it! twit_hndl_BankA# getcollegeready# contest
# want those moneys! twit_hndl_BankA# getcollegeready# contest
# want to win twit_hndl_BankA# getcollegeready# contest
# watching the conveyor belt like# BankB pack9# hurryup# pickmarjala???? twit_hndl_BankA# getcollegeready# contest# pickheralready
# way to go BankA, youre doing good things with this# getcollegeready# contest
# we  ve got your BankB  for college expenses. join our live event.# getcollegeready# contest spr. ly/ 6016beBankCo INTERNET
# well the twit_hndl_BankA# getcollegeready# contest is definitely unique. i  m in.
# BankA = clutch# getcollegeready# contest
# BankA = Name goat# getcollegeready# contest
# BankA and cool college stuff# getcollegeready# contest
# BankA BankB packs# getcollegeready# contest
# BankA BankB packs... get to college!# getcollegeready# contest
# BankA bank rules# getcollegeready
# BankA can help anyone start saving!# getcollegeready# contest
# BankA Name# BankA bank# getcollegeready# contest
# BankA college BankB pack contest contest.# getcollegeready# contest
# BankA cool cargo# getcollegeready# contest
# BankA does loans# getcollegeready# contest
# BankA does sweepstakes# getcollegeready# contest
# BankA drop bag 6# getcollegeready# contest
# BankA enables life changes# getcollegeready# contest
# BankA Name# getcollegeready# contest
# BankA game on# getcollegeready# contest
# BankA gives away prizes# getcollegeready# contest
# BankA go# getcollegeready# contest
# BankA got my BankB .. pack i  m watching a conveyor belt move live on screen and loving it.# getcollegeready# contest
# BankA has a good reputation for respect, otherwise# getcollegeready# contest
# BankA has a great college plan! getcollegeready# contest
# BankA has a great plan for college# getcollegeready# contest
# BankA has all your banking needs# getcollegeready# contest
# BankA has the best staff tho.# getcollegeready# contest
# BankA help me# getcollegeready# contest
# BankA helping me get ready for my next adventure... college!# getcollegeready# contest
# BankA helps me strive# getcollegeready# contest
# BankA helps you get ready for college# getcollegeready# contest
# BankA hopefully is seeing all this!# getcollegeready# contest
# BankA Name are you today?# getcollegeready# contest
# BankA i didnt win prepare to hear from my lawyers# getcollegeready# contest
# BankA i have 6 kids in Name# getcollegeready# contest
# BankA i need a loan# getcollegeready# contest
# BankA i need a new BankB pack# getcollegeready# contest
# BankA i rebanke need a laptop# getcollegeready# contest
# BankA Name ready# getcollegeready# contest
# BankA if you love me, give me this BankB pack!# getcollegeready# contest
# BankA is a great bank for doing this. you the real Name# getcollegeready# contest
# BankA is amazing to give us this opportunity!!# getcollegeready# contest
# BankA is awesome!!!# getcollegeready# contest
# BankA is awesome# contest# getcollegeready
# BankA is awesome# getcollegeready# contest
# BankA is awesome for this giveaway, for real.# getcollegeready# contest
# BankA is awesome!# getcollegeready# contest
# BankA is college ready# getcollegeready# contest
# BankA is great# getcollegeready# contest
# BankA is great!!# getcollegeready# contest
# BankA is my bank# getcollegeready# contest
# BankA is my pack to school place# getcollegeready# contest
# BankA is number 1# getcollegeready# contest
# BankA is ok in my book# getcollegeready# contest
# BankA is on fleek because they support an education# getcollegeready# contest
# BankA is running a great contest to bring awareness to their college prep products! INTERNET# getcollegeready# contest
# BankA is sending me to college.# getcollegeready# contest
# BankA is so great for doing this# getcollegeready# contest
# BankA is taking over timelines with this contest# getcollegeready# contest
# BankA is the best# getcollegeready# contest
# BankA is the best twit_hndl_BankA# getcollegeready# contest
# BankA is the best bank in the world!# getcollegeready# contest
# BankA is the best bank!# getcollegeready# contest
# BankA is the best bank# getcollegeready# contest
# BankA is the best way to help college bound students# getcollegeready# contest
# BankA is the bomb!!# getcollegeready# contest
# BankA is the greatest for this# getcollegeready# contest
# BankA is the one# getcollegeready# contest
# BankA is the place!# getcollegeready# contest
# BankA is the real Name# getcollegeready# contest
# BankA is the stepping stone# getcollegeready# contest
# BankA is the truth.# getcollegeready# contest
# BankA is trying to help students in need# getcollegeready# contest
# BankA is your BankB  to school place# getcollegeready# contest
# BankA let me win.# getcollegeready# contest
# BankA makes it easy# getcollegeready# contest
# BankA my dog ate my remote# getcollegeready# contest
# BankA need some more coffee# getcollegeready.# contest
# BankA on fleek# getcollegeready# contest
# BankA pack to college.# getcollegeready# contest
# BankA pack to school!!!!! please me!# getcollegeready# contest
# BankA pick Name!# getcollegeready# contest
# BankA pick Name!!!# getcollegeready# contest
# BankA ready!!# getcollegeready# contest
# BankA rebanke helped me strbankehten my money out! s/ o the alabama branch ran by Name Name!!.# getcollegeready# contest
# BankA rocks.# getcollegeready# contest
# BankA rocks doing this contest# getcollegeready# contest
# BankA rocks i don  t know what  s more exBankCng  college or trying to win these prizes.# getcollegeready# contest
# BankA rocks!# getcollegeready# contest
# BankA Name!# getcollegeready# contest
# BankA rocks!!# getcollegeready# contest
# BankA rules!# getcollegeready# contest
# BankA seriously helped me out! i talked to Name Name at the alabama branch about managing my money# getcollegeready# contest
# BankA Name my education thank u# getcollegeready# contest
# BankA sure is a great day to be a duck# getcollegeready# contest
# BankA wants to help someone# getcollegeready# contest
# BankA went allllll out for this??????# getcollegeready# contest
# BankA who moved the box# getcollegeready# contest
# BankA why are you not in kentucky?# getcollegeready# contest
# BankA will help the college student# getcollegeready# contest
# BankA you can keep 250 dollars if you give me the bag# getcollegeready# contest
# BankA-ness is next to godliness# getcollegeready# contest
# BankA, help me win# getcollegeready# contest
# BankA, i have a question# getcollegeready# contest
# BankA, Name ready to win!# getcollegeready# contest
# BankA, me, and another semester!! get Name!!# getcollegeready# contes
# BankA, thank you for the chance to win# getcollegeready# contest
# BankA, youre nuts for doing this contest but i love you for it# getcollegeready# contest
# BankA!# getcollegeready# contest
# BankA! twit_hndl_BankA# getcollegeready# contest
# BankA!!!# getcollegeready# contest
# BankA!!!!# getcollegeready# contest
# BankA.# getcollegeready# contest
# BankAs# getcollegeready# contest
# BankA # getcollegeready# contest
# BankA  are you hiring?!?!# getcollegeready# contest
# BankA  fan!# getcollegeready# contest
# BankA  if anyone creeps on my tweets any time soon, i feel sorry for them# getcollegeready# contest# atawacada  INTERNET
# BankA  is good to me# getcollegeready# contest
# BankA  is life# getcollegeready# contest
# BankA : amied027 thanks for joining us for the# getcollegeready contest. email us by 8/13/15 INTERNET for prize ins
# BankA : Name Name! thanks for sharing.# getcollegeready freddie Name
# BankA : bonita19yaris thanks Name 4 joining the# getcollegeready contest. email us by 8/13/15 at INTERNET 4 prize claim ins
# BankA : boxerbg thanks for joining us for the# getcollegeready contest. email us by 8/13/15 INTERNET for prize inst
# BankA : caronv302 thanks for joining the# getcollegeready contest. email us by 8/13/15 at INTERNET for prize claim in
# BankA : Name Name for joining the# getcollegeready contest. email us by 8/13/15 at INTERNET for prize claim in
# BankA : Name Name for joining the# getcollegeready contest. email us by 8/13/15 INTERNET for prize instru
# BankA : defriend thanks for joining us for the# getcollegeready contest. email us by 8/13/15 INTERNET for prize ins
# BankA : defriend thanks for sharing. congrats!# getcollegeready# contest Name
# BankA : do you know how much you need to borroBankA or college? try our calculator.# getcollegeready  INTERNET
# BankA : esker3 thanks for joining the# getcollegeready contest. email us by 8/13/15 at INTERNET for prize claim instr
# BankA : future46er thanks Name for joining the# getcollegeready contest. email us by 8/13/15 INTERNET for prize instruct
# BankA : get all the college financial know-how by taking our# getcollegeready quiz now.  INTERNET
# BankA : Name Name 4 joining the# getcollegeready contest. email us by 8/13/15 at INTERNET 4 prize
# BankA : Name are some helpful tips and tools for managing your money so you can# getcollegeready.  INTERNET
# BankA : Name Name 4 joining the# getcollegeready contest. email by 8/13/15 at INTERNET 4 prize
# BankA : if you haven  t won yet, keep tweeting with# getcollegeready.# contest spr. ly/ 6016b1oeq INTERNET
# BankA : Name Name for joining the# getcollegeready contest. email us by 8/13/15 at INTERNET for prize instruct
# BankA : kellielacy thanks for joining us 4 the# getcollegeready contest. email us by 8/13/15 INTERNET for prize ins
# BankA : lvsmgm thanks for joining us for the# getcollegeready contest. email us by 8/13/15 INTERNET for prize instr
# BankA : Name Name for joining the# getcollegeready contest. email us by 8/13/15 INTERNET for prize in
# BankA : Name Name for joining the# getcollegeready contest. email us by 8/13/15 INTERNET for prize ins
# BankA : myrawrsepanski thanks for joining the# getcollegeready contest. email us by 8/13/15 at INTERNET for prize ins
# BankA : redasp07 thanks for joining us for the# getcollegeready contest. email us by 8/13/15 INTERNET for prize ins
# BankA : reyyes29 thanks for joining the# getcollegeready contest. email us by 8/13/15 at INTERNET for prize claim ins
# BankA : reyyes29 woohoo! enjoy and thank you again for participating in# getcollegeready. Name
# BankA : rodgersmarie thanks for joining the# getcollegeready contest. email us by 8/13/15 INTERNET for prize instru
# BankA : rudgrrr thanks for joining us for the# getcollegeready contest. email us by 8/13/15 INTERNET for prize inst
# BankA : Name Name for joining us the# getcollegeready contest. email us by 8/13/15 INTERNET for prize inst
# BankA : sjhendrix06 thanks for joining the# getcollegeready contest. email us by 8/13/15 INTERNET for prize instruc
# BankA : thanks for joining our event yesterday. congrats to the winners.# getcollegeready# contest
# BankA : toebee84 thanks for joining us for the# getcollegeready contest. email us by 8/13/15 at INTERNET for prize in
# BankA : Name Name for joining the# getcollegeready contest. email us by 8/13/15 INTERNET for prize instruc
# BankA : Name. move the conveyor belt. you could win a prize.# getcollegeready# contest  INTERNET
# BankA : we have winners already. are you next? keep tweeting with# getcollegeready.# contest  INTERNET
# BankA : we simplified the journey to financial aid to 5 steps. start yours now.# getcollegeready  INTERNET
# BankA : we  ve got your BankB  for college expenses. join our live event.# getcollegeready# contest  INTERNET
# BankA : you could win what  s in this BankB pack. join our event to see.# getcollegeready# contest  INTERNET
# BankA : you have options when it comes to paying for college. learn more and# getcollegeready.  INTERNET
# what better way to start the semester with twit_hndl_BankA# getcollegeready# contest
# what banke do you know that cares about education as much as BankA?# getcollegeready# contest
# what to say? i want to win# getcollegeready# contest twit_hndl_BankA
# whats in the BankB pack fam??# contest# getcollegeready twit_hndl_BankA
# whats in the pack? follow twit_hndl_BankA to find out# getcollegeready# contest
# whats inside?!# getcollegeready# contest twit_hndl_BankA
# what  s in your BankB pack? twit_hndl_BankA is giving away prizes for school today! bit. ly/ 1dtrpig# getcollegeready
# whetwit_hndl_BankA whee# contest# getcollegeready
# wheres my luck# getcollegeready# contest twit_hndl_BankA
# who dey BankA BankA# getcollegeready# contest
# who do we call when we want great service the one and olny BankA# getcollegeready# contest
# who doesnt love twit_hndl_BankA# getcollegeready# contest
# who ever else needs money or supplies for college; follow BankA!# getcollegeready# contest
# who is hungry BankA# getcollegeready# contest
# who is the best bank in the land BankA# getcollegeready# contest
# why did the chicken cross the road BankA# getcollegeready# contest
# why dont you fall bag? twit_hndl_BankA# getcollegeready# contest
# why BankA is cool# getcollegeready# contest
# wiigtwit_hndl_BankA# getcollegeready# contest almost there
# will it drop this time!! twit_hndl_BankA# getcollegeready# contest
# Name that$$ twit_hndl_BankA# getcollegeready# contest
# win?# getcollegeready# contest twit_hndl_BankA
# win# getcollegeready# contest twit_hndl_BankA
# win a BankB pack full of# getcollegeready prizes...# ronr# noletup# paid# BankA  INTERNET INTERNET
# win a BankB pack thanks to BankA# getcollegeready# contest
# win a BankA BankB  pack full of goodies!# getcollegeready# contest
# win Name twit_hndl_BankA# getcollegeready# contest
# win that$$$$$$ money twit_hndl_BankA# getcollegeready# contest
# win whats in the BankB pack(or just make it fall off the conveyor)by tweeting# getcollegeready &# contest! INTERNET
# win win win please# getcollegeready# contest twit_hndl_BankA
# win with twit_hndl_BankA# getcollegeready# contest
# win!# contest# getcollegeready twit_hndl_BankA
# win!!!!!!!!!! BankA# getcollegeready# contest
# win!? twit_hndl_BankA# getcollegeready# contest
# winit twit_hndl_BankA# getcollegeready# contest
# winnin twit_hndl_BankA# getcollegeready# contest
# winnnn twit_hndl_BankA# getcollegeready# contest
# with BankA , everything is possible.# getcollegeready# contest
# wont let me change it on the website twit_hndl_BankA does it work just to tweet on twitter? site dont work.# getcollegeready# contest
# woo getting closer expresso# getcollegeready# contest twit_hndl_BankA
# would love a new BankB pack from my bank twit_hndl_BankA BankA-# getcollegeready# contest
# would love to# getcollegeready with twit_hndl_BankA via# contest Name crossed!;)
# wow!! this is exBankCng!! BankA  helping college students! thank you!!!# getcollegeready# contest
# wwBankAd(what would BankA do )?# getcollegeready# contest
# yassss tell them??????# getcollegeready twit_hndl_BankA# contest
# yay. BankA# getcollegeready# contest
# yeah BankA# getcollegeready# contest
# yes i love this twit_hndl_BankA BankB  to school promo! you should try it!# getcollegeready# contest
# yes this twit_hndl_BankA BankB  to school promo is fun! you should try it!# getcollegeready# contest
# yes! learning is the only way to go.# getcollegeready# contest twit_hndl_BankA
# yes!... ret_twit twit_hndl_BankA Name can win what  s in this BankB pack. join to see.# getcollegeready spr. ly/ 6015becwt INTERNET# ronr
# yes. BankA.# getcollegeready# contest
# yogirlmindless: goo. gl/ y8zwqm BankA  ive Name been tweeting since 12 pm est!# getcollegeready# contest
# you are cool twit_hndl_BankA# getcollegeready.# contest
# you college ready yet??# contest# getcollegeready twit_hndl_BankA
# you could win what  s in this BankB pack. join our event to see.# getcollegeready# contest spr. ly/ 6015becwt INTERNET
# you guys rock so generous & awesome prizes!!!# getcollegeready# contest twit_hndl_BankA
# you guys rock with awesome prizes!# getcollegeready# contest twit_hndl_BankA
# you Name rock! so generous! twit_hndl_BankA# getcollegeready# contest
# you guys rock! so generous!# getcollegeready# contest twit_hndl_BankA
# Name pretty BankA# getcollegeready# contest
# your teen heading to# college? twit_hndl_BankA is giving BankB packs away today! bit. ly/ 1dtrpig# getcollegeready INTERNET
# Messages Remaining: 166129

# %%
percent_remaining = 100-(len(prune7)/len(data))*100
print('Percent of tweets remaining after prune:', percent_remaining)
# Out:
# Percent of tweets remaining after prune: 24.539765946537074

# %%
with open('news-classified.json') as file:
    labeled_msgs = json.load(file)

msgs = []
for msg in labeled_msgs:
    msgs.append(msg['FullText'])

# %%
from collections import Counter
from sklearn.preprocessing import LabelEncoder

with open('news-classified.json') as file:
    labeled_msgs = json.load(file)
file.close()
    
with open('news-classified2.json') as file2:
    labeled_msgs2 = json.load(file2)
file2.close()

for msg in labeled_msgs2:
    labeled_msgs.append(msg)
    
print(len(labeled_msgs))
    
print('read %d labeled tweets' % len(labeled_msgs))

label_map = {'n': 'not news', 'y': 'news'}
labels = ['news', 'not news']

for msg in labeled_msgs:
    msg['News'] = label_map[msg['News']]
    
label_encoder = LabelEncoder()
label_encoder.fit(labels)
y = label_encoder.transform([msg['News'] for msg in labeled_msgs])             
print('Label distribution=%s' % Counter(msg['News'] for msg in labeled_msgs).most_common(2))
# Out:
# 400
# read 400 labeled tweets
# Label distribution=[('not news', 275), ('news', 125)]

# %% [markdown]
# Tokenizing:
#
# a. converted to lower case
# b. remove punctuation (except for internal punctuation such as apostrophes and hyphens)
# c.  removed characters repeated more than twice consecutively
# d. collapsed all digits to the same character
# e. changed all mentions of BankA, BankB, BankC, BankD to bankabcd
# f. changed all mentions of #BankA, #BankB, #BankC, #BankD to #bankabcd
# g. changed all mentions of twit_hndl_BankA, twit_hndl_BankB, twit_hndl_BankC, twit_hndl_BankD to twit_hndl_bankabcd

# %%
# Tweet tokenizer.
import re
import string
def tokenize(text):
    punc_re = '[' + re.escape(string.punctuation) + ']'
    text = text.lower()
    text = re.sub(r'(.)\1\1\1+', r'\1', text)
    text = re.sub(r'[0-9]', '9', text)
    text = re.sub('bank(\S+)', 'bankabcd', text)
    text = re.sub('#bank(\S+)', '#bankabcd', text)
    text = re.sub('twit_hndl_bank(\S+)', 'twit_hndl_bankabcd', text)
    toks = []
    for tok in text.split():
        tok = re.sub(r'^(' + punc_re + '+)', r'\1 ', tok)
        tok = re.sub(r'(' + punc_re + '+)$', r' \1', tok)
        for subtok in tok.split():
            if re.search('\w', subtok):
                toks.append(subtok)
    return toks

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np

vectorizer = TfidfVectorizer(decode_error='ignore', ngram_range=(1, 2), max_df=1., min_df=2,
                             use_idf=True, tokenizer=tokenize, binary=False, norm='l2')
X = vectorizer.fit_transform(msg['FullText'] for msg in labeled_msgs)
print('Vectorized %d tweets. Found %d terms.' % (X.shape[0], X.shape[1]))
features = np.array(vectorizer.get_feature_names())
# Out:
# Vectorized 400 tweets. Found 1366 terms.

# %%
from sklearn.cross_validation import cross_val_score, KFold
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, precision_recall_curve, precision_recall_fscore_support
from tabulate import tabulate

def confusion(truths, preds, labels):
    m = confusion_matrix(truths, preds)
    m = np.vstack((labels, m))
    m = np.hstack((np.matrix([''] + list(labels)).T, m))
    return tabulate(m.tolist(), headers='firstrow')

def top_coef(clf, vocab, n=10):
    if len(clf.classes_) == 2:
        coefs = [clf.coef_[0], -clf.coef_[0]]
    else:
        coefs = clf.coef_
    for li, label in enumerate(clf.classes_):
        print('\nCLASS %s' % label)
        coef = coefs[li]
        top_coef_ind = np.argsort(coef)[::-1][:n]
        top_coef_terms = vocab[top_coef_ind]
        top_coef = coef[top_coef_ind]
        print('\n'.join(['%s\t%.3f' % (term, weight) for term, weight in zip(top_coef_terms, top_coef)]))

def do_cv(X, y, labels, nfolds=10):
    cv = KFold(len(y), nfolds, random_state=123456)
    preds = []
    truths = []
    for train, test in cv:
        clf = LogisticRegression(class_weight='balanced', solver='liblinear', intercept_scaling=.3)
        clf.fit(X[train], y[train])
        preds.extend(clf.predict(X[test]))
        truths.extend(y[test])
    print('accuracy=%.5f' % (accuracy_score(truths, preds)))
    print(classification_report(truths, preds, target_names=labels))
    print(confusion(truths, preds, labels))
    clf = LogisticRegression(class_weight='balanced', solver='liblinear', intercept_scaling=.3)
    clf.fit(X, y)
    return clf, truths, preds
clf, truths, preds = do_cv(X, y, label_encoder.classes_, 10)
top_coef(clf, features, 5)
# Out:
# accuracy=0.83250
#              precision    recall  f1-score   support
#
#        news       0.70      0.82      0.75       125
#    not news       0.91      0.84      0.87       275
#
# avg / total       0.84      0.83      0.84       400
#
#             news    not news
# --------  ------  ----------
# news         103          22
# not news      45         230
#
# CLASS 0
# i	1.702
# my	1.396
# you	1.181
# twit_hndl_bankabcd	1.181
# and	0.818
#
# CLASS 1
# internet	1.738
# name	1.633
# ly	1.394
# bankabcd name	1.231
# rating	1.182

# %%
def do_cv_thresh(X, y, labels, thresh=.5, nfolds=10):
    cv = KFold(len(y), nfolds, random_state=123456)
    preds = []
    truths = []
    probas = []
    for train, test in cv:
        clf = LogisticRegression(class_weight='balanced')
        clf.fit(X[train], y[train])
        proba = clf.predict_proba(X[test])
        if len(probas) == 0:
            probas = proba
        else:
            probas = np.vstack((probas, proba))
        preds.extend(clf.predict(X[test]))
        truths.extend(y[test])
                       
    # Now deterime best threshold for each class to maximize F1.
    thresholds = np.arange(1,21) * .05
    print(thresholds)
    for i, l in enumerate(labels):
        print('label=', l)
        for thresh in thresholds:
            newpreds = [1 if l2==i and probas[j][i] >= thresh else 0 for j, l2 in enumerate(preds)]
            newtruths = [1 if t==i else 0 for t in truths]
            #print Counter(newpreds)
            print(thresh, precision_recall_fscore_support(newtruths, newpreds, average='binary'))
    print('accuracy=%.3f' % (accuracy_score(truths, preds)))
    print(classification_report(truths, preds, target_names=labels))
    print(confusion(truths, preds, labels))
    clf = LogisticRegression(class_weight='balanced')
    clf.fit(X, y)
    return clf, truths, preds

clf, truths, preds = do_cv_thresh(X, y, label_encoder.classes_, .1, 10)
# Out:
# [ 0.05  0.1   0.15  0.2   0.25  0.3   0.35  0.4   0.45  0.5   0.55  0.6
#   0.65  0.7   0.75  0.8   0.85  0.9   0.95  1.  ]
# label= news
# 0.05 (0.71739130434782605, 0.79200000000000004, 0.75285171102661608, None)
# 0.1 (0.71739130434782605, 0.79200000000000004, 0.75285171102661608, None)
# 0.15 (0.71739130434782605, 0.79200000000000004, 0.75285171102661608, None)
# 0.2 (0.71739130434782605, 0.79200000000000004, 0.75285171102661608, None)
# 0.25 (0.71739130434782605, 0.79200000000000004, 0.75285171102661608, None)
# 0.3 (0.71739130434782605, 0.79200000000000004, 0.75285171102661608, None)
# 0.35 (0.71739130434782605, 0.79200000000000004, 0.75285171102661608, None)
# 0.4 (0.71739130434782605, 0.79200000000000004, 0.75285171102661608, None)
# 0.45 (0.71739130434782605, 0.79200000000000004, 0.75285171102661608, None)
# 0.5 (0.71739130434782605, 0.79200000000000004, 0.75285171102661608, None)
# 0.55 (0.77477477477477474, 0.68799999999999994, 0.72881355932203395, None)
# 0.6 (0.81052631578947365, 0.61599999999999999, 0.69999999999999996, None)
# 0.65 (0.81944444444444442, 0.47199999999999998, 0.59898477157360397, None)
# 0.7 (0.78723404255319152, 0.29599999999999999, 0.43023255813953487, None)
# 0.75 (0.73333333333333328, 0.17599999999999999, 0.28387096774193549, None)
# 0.8 (0.7142857142857143, 0.080000000000000002, 0.14388489208633096, None)
# 0.85 (0.66666666666666663, 0.016, 0.03125, None)
# 0.9 (0.0, 0.0, 0.0, None)
# 0.95 (0.0, 0.0, 0.0, None)
# 1.0 (0.0, 0.0, 0.0, None)
# label= not news
# 0.05 (0.9007633587786259, 0.85818181818181816, 0.87895716945996272, None)
# 0.1 (0.9007633587786259, 0.85818181818181816, 0.87895716945996272, None)
# 0.15 (0.9007633587786259, 0.85818181818181816, 0.87895716945996272, None)
# 0.2 (0.9007633587786259, 0.85818181818181816, 0.87895716945996272, None)
# 0.25 (0.9007633587786259, 0.85818181818181816, 0.87895716945996272, None)
# 0.3 (0.9007633587786259, 0.85818181818181816, 0.87895716945996272, None)
# 0.35 (0.9007633587786259, 0.85818181818181816, 0.87895716945996272, None)
# 0.4 (0.9007633587786259, 0.85818181818181816, 0.87895716945996272, None)
# 0.45 (0.9007633587786259, 0.85818181818181816, 0.87895716945996272, None)
# 0.5 (0.9007633587786259, 0.85818181818181816, 0.87895716945996272, None)
# 0.55 (0.91983122362869196, 0.79272727272727272, 0.85156249999999989, None)
# 0.6 (0.97156398104265407, 0.74545454545454548, 0.84362139917695478, None)
# 0.65 (0.9887640449438202, 0.64000000000000001, 0.77704194260485648, None)
# 0.7 (0.99259259259259258, 0.48727272727272725, 0.65365853658536588, None)
# 0.75 (1.0, 0.33454545454545453, 0.50136239782016345, None)
# 0.8 (1.0, 0.15636363636363637, 0.27044025157232709, None)
# 0.85 (1.0, 0.02181818181818182, 0.042704626334519581, None)
# 0.9 (0.0, 0.0, 0.0, None)
# 0.95 (0.0, 0.0, 0.0, None)
# 1.0 (0.0, 0.0, 0.0, None)
# accuracy=0.838
#              precision    recall  f1-score   support
#
#        news       0.72      0.79      0.75       125
#    not news       0.90      0.86      0.88       275
#
# avg / total       0.84      0.84      0.84       400
#
#             news    not news
# --------  ------  ----------
# news          99          26
# not news      39         236
# /usr/lib64/python3.4/site-packages/sklearn/metrics/classification.py:1074: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
final_prune = prune7
X_raw = vectorizer.transform(msg['FullText'] for msg in final_prune)

# %%
# Relabel all unlabeled tweets.
probas_raw = clf.predict_proba(X_raw)
preds_raw = clf.predict(X_raw)

print('label distribution on messages: %s' % Counter(preds_raw).most_common(2))
print('1 is news, 0 is not news')
for msg, pred in zip(final_prune, preds_raw):
    msg['News'] = labels[pred]
# Out:
# label distribution on messages: [(1, 99402), (0, 67186)]
# 1 is news, 0 is not news

# %%
#read some news tweets
for msg in final_prune[300:900]:
    if msg['News'] is 'news':
        print(msg['FullText'])
# Out:
# . twit_hndl_BankB twit_hndl joins twit_hndl: ow. ly/ qvyws- Name bank will offer execution and clearing services
# . twit_hndl_BankB_community set Name to finance preservation Name of 1,400 public housing units units under Name. f. rad plan bit. ly/ 1uqxzry
# . twit_hndl says Name Name note on BankB is the finest trolling its seen on a research note: ow. ly/ rcior
# . twit_hndl_BankC and BankD  Name embrace new Name service INTERNET
# . twit_hndl_BankC dangles us$ 100k carrot at Name developers bit. ly/ 1gzm8t5 INTERNET
# . twit_hndl_BankC strikes$ 180m settlement with Name over allegedly misleading marketing for two hedge funds ow. ly/ r333l
# . twit_hndl stresses the importance of community, leaders & business partnerships# beattheheat twit_hndl twit_hndl_BankD INTERNET
# . twit_hndl chooses twit_hndl_BankC for custody: ow. ly/ qvyvq- representing assets of$ 29.1 billion
# . twit_hndl hires former BankA Name cto as Name of tech product development. twit_hndl has details bit. ly/ 1njkkqe
# . twit_hndl twit_hndl twit_hndl it says BankB Name nuts you pro life wing nut. time to delete your account INTERNET
# . twit_hndl snaps up twit_hndl_BankC alternative investment for$ 425m: ow. ly/ r56hg- to increase presence in global fund admin admin space
# . twit_hndl, twit_hndl_BankA survey says americans still wary of economy, impacting investment, spending choices. bit. ly/ 1m0kpij
# . twit_hndl_BankA enhances floor plan platform with twit_hndl# dealers# inventory ow. ly/ qxe9c
# . twit_hndl_BankA insurance brokers win business insurance magazine Name business insurance magazine 40 under 40 broker awards twit_hndl via twit_hndl INTERNET
# . Name bank roll??, dont BankD hoes?? too many fishes in that sea?? Name??
# . wants a Name office manager(1871_24875397)in BankD city, Name: bit. ly/ 1hlkvwq
# ... and Name why Name mine will not proceed according to ex-BankC analyst INTERNET  via twit_hndl
# ... blinky blinky blink... lexxx @ BankB BankB INTERNET/
# ... up Name.. cursing BankD BankD bank Name.. too Name too be Name but Name Name.. add it Name Name series of unfortunate events..
# ... wow...? BankB will pay a record amount of money to settle with the united states department of justice of Name.
# .... Name boomed on... i want to propose f u get some.... Name Name Name new Name yankees new Name Name new Name Name true religion brand Name Name & Name. 1800# Name Name# green(thats my baby )# no fighting babe i love you## yes# lol# son# hammer# beyonc # 7 year theory# BankD and capitol one bank card.... Name Name.... for 799 million dollars..... Name my wife.......... gucci shoes Name.... lets play for 15 million today if nobody wants to get the deal through.... and kobe has to play for 7 more years.... 100 Name Name.... still no response.... whats hove doing.... rolls-royce motor cars then motor Name Name go to my room... only because i have to live to let it live again.... movies.... tiffany & Name.
# ....... yeah Name have to go by chinatown afterwork. need to hit BankB Name
# ... congrats rizza ostaya Name Name.. just heard d news BankD  Name kna dw work nxt wik..??? nglevel up kna gudman.. pan. international na.. see yah...
# ... credit Name... satin alindi Name... Name Name... satin alindi Name... BankB corporation... satin alindi Name...
# ... goldir_msgan sachs Name# Name. home depot depot# Name. intel# intc. ibm# ibm. Name & Name# Name. BankD  BankD# BankD . Name# Name. Name# Name...
# ... home depot depot# Name Name# intc ibm# ibm Name & Name# Name BankD  BankD# BankD m mcdonalds Name# mcd merck Name# mrk microsoft Name# Name Name# Name...
# ... home depot depot# Name. intel# intc. ibm# ibm. Name & Name# jnj BankD  BankD BankD  BankD# BankD m mcdonalds Name# mcd merck Name# mrk microsoft Name# msft nike Name# Name...
# ... ibm# ibm. Name & Name# Name. BankD  BankD BankD# BankD . Name# Name. Name# Name. microsoft# msft. Name# Name. pfizer# Name...
# ... no mejor as ! classic abbott Name and Name. have badge Name BankD 8mm silent film from Name Name. Name film transfer system. high quality direct digital frame by fram...
# ... Name/ scotland central... uydu proje i Name Name  in Name Name... Name Name Name stirling bu proje kapsaminda Name Name... 33   nemli firma merkez ve yakinda Name Name Name Name... Name t lock. Name la Name. louis Name. Name. kensington. labrador. napapijri. anapurna. Name/ cork. Name/ new Name. Name. Name. Name. Name. Name Name. bristol cars 2019 years. pizza hut. Name. douwe egberet_twits.the howdah tea tea & coffee Name. Name. Name television. bang & Name. natuzzi. mechanics bank bank. castle rock rock water Name. gorenje. credit Name. commerzbank ag Name. BankB corporation. c. a. Name and company. caribou coffee company. Name van Name Name. timothy s coffees Name coffees of the world Name. Name Name chocolate. interscope records records shop. ag barr Name 1875 Name. harkila. bruar. glenmuir. Name Name watches. Name watches. tag heuer Name. Name Name. chevignon. loake shoemakers. Name Name 1874. Name of ireland. pampeano. vivella 1784. tim horet_twitons inc Name Name 1964. caterpillar shoe. Name Name. Name chocolate. kar s s nuts. Name. corneliani. strellson. Name. d & g. paco rabanne Name. Name. scotch & soda. Name & marshall. timberland ve avm Name Name yapilacaktir bu avm de Name Name 112 scientology Name nu Name eden ma aza bulunacaktir... 33 +112...
# ... we salute you BankC! music video by Name/ dc performing for Name about Name rock(Name salute Name ).(Name at Name Name 2009 )(c)2011 leidseplein presse b.v. Name b. Name.
# .. Name Name story... BankA, Name barriers warriors join forces with Name brown band: BankA.. bit. ly/ 1nqxhp0... csrwire...
# . aandriotis twit_hndl_BankD twit_hndl_BankA BankA make it easier to get# jumbo mortgages INTERNET. twit_hndl mapped them bit. ly/ 1hxjcfj
# . aarp twit_hndl_BankC twit_hndl twit_hndl twit_hndl at# connectedhealthsummit15 INTERNET INTERNET
# . alfrededmondjr giving keynote at twit_hndl# smallbusinessmatters summit twit_hndl_BankA twit_hndl twit_hndl INTERNET
# . ambestco and twit_hndl_BankD are among ratings firms weighing in on twit_hndl decision to not sell its life/ annuity biz bit bit. ly/ 1p91yje
# . americaspromise & twit_hndl_BankC Name announce 12# youthoppfund community partners community Name! buff. ly/ 1jrjygq# pathways2progress
# . americaspromise & twit_hndl_BankC Name want to help connect youth to job opportunities. bit. ly/ 1ju2sds# youthoppfund# pathways2progress
# . americaspromise & twit_hndl_BankC fdns# youthoppfund will impact 3,800 low-income# youth in 10 BankCes. buff. ly/ 1pvczg6# pathways2progress
# . Name- Name BankB twit_hndl_BankB twit_hndl funding# plannedparenthood, twit_hndl# christiansunite# defundpp# ppsellsbabyparts
# . Name report on latest twit_hndl_BankA twit_hndl# smallbiz index index: small business Name optimism Name along INTERNET  twit_hndl
# . appleinsider: BankA upgrades Name stock to outperform, says recent correction is an overreaction ainsdr. co/ bymh9s/ s/ rqtw
# . aratirandolphBankA has led BankAs brand journalism efforts by launching INTERNET.# raganchat
# . asus BankA BankA Name is electric! incoming freshmen cant stop cheering the Name devil Name! INTERNET
# . atlhlds mayor Name praised lance hubeny Name for his twit_hndl_BankA award. via twit_hndl. bit. ly/ 1hcogmv INTERNET
# . austin_police seek robbery suspect that got away with an unknown sum of$ from BankA. bit. ly/ 1tuxd4g INTERNET
# . Name Name$ 139m Name Name &$ 200m Name Name Name by twit_hndl_BankD INTERNET  via twit_hndl
# . Name Name$ 139m asset-BankB ed securitization Name &$ 200m Name Name Name by twit_hndl_BankD INTERNET  via twit_hndl
# . balajis had they used INTERNET, BankD  Name might have saved few billion dollars INTERNET  INTERNET
# . twit_hndl_BankB + twit_hndl provide$ 370m loan to minskoff to refinance 400k sf 51 Name place# office ow. ly/ qzzvw twit_hndl
# . twit_hndl_BankB Name summer# youth with employment opportunities Name via twit_hndl bit. ly/ 1mb5nq6# expandedlearning
# . twit_hndl_BankB cto Name# Name Name, security ow. ly/ qubjc twit_hndl INTERNET
# . twit_hndl_BankB illustrates investment themes with maps: people, earth, innovation, government, markets. bit. ly/ 1hod8rn
# . twit_hndl_BankB is gaining control of conversation about its brand. ad recall is up,(bad)press recall down bit. ly/ 1iel81g twit_hndl
# . twit_hndl_BankB is pulling wealthy clients money from billionaire paulsons hedge fund fund: bit. ly/ 1mpnBankCx
# . twit_hndl_BankB millennial marketing marketing pays off Name Name bit. ly/ 1njlebe via twit_hndl INTERNET
# . twit_hndl_BankB planning to lend$ 770 million to protect# affordablehousing in Name. hubs. ly/ h0114l50 INTERNET
# . twit_hndl_BankB pulls clients money from Name Name fund: bit. ly/ 1mpnBankCx
# . twit_hndl_BankB Name Name = > twit_hndl calls out a# corpgov sleight of hand INTERNET c twit_hndl twit_hndl
# . twit_hndl_BankB thank you4 twit_hndl Name Name frm vienna s imperialcollections.# thedeathofcleopatra INTERNET
# . bankunited taps taps# BankB banker to lead west coast retail banking in# tampa bizj. us/ 1iss1q via twit_hndl
# . bipinsahni, driver of financial technology innovations twit_hndl_BankA, tops Name list twit_hndl shar. es/ 1t8qyu
# . bipinsahni, who moves financial tech innovations forward twit_hndl_BankA, tops Name list twit_hndl shar. es/ 1t8qyu
# . twit_hndl_BankB_community + twit_hndl finance restoration of 1400 units of public housing in Name bit. ly/ 1nxnwpg twit_hndl# rad twit_hndl
# . twit_hndl_BankB Name Name# environmental# Name Name to$ 125b by 2025 sbshare. co/ 1vltgcr
# . twit_hndl_BankB_community grants money to 40 nonprofits, including twit_hndl, to focus on# workforce &# education. ow. ly/ qtsnz
# . twit_hndl_BankB_news BankB BankB announces industry-leading$ 125 Name environmental business initiative bit. ly/ 1ktevv8
# . twit_hndl_BankB_news environmental business initiative to$ 125b by 2025 ow. ly/ qlkvg via twit_hndl# ecosystem
# . business reported that twit_hndl_BankB resigned as agent for arch coal coal s lenders ow. ly/ qqgal
# . business reports twit_hndl_BankD & its lawyers are being sued by one of the participants in the$ 1.5 Name loan BankD  made to Name. ow. ly/ qta5l
# . business says that twit_hndl_BankA has emerged as a front-runner for Name railcar unit. ow. ly/ rudvl
# . businsmagazine names 2 twit_hndl_BankA insurance leaders to its 40 under 40 broker Name list: bit. ly/ 1pnzjy7 INTERNET
# . BankCitweets twit_hndl but BankC says failure to slow Name will cost global gdp Name$ 44 tn by 2060 twit_hndl INTERNET
# . BankCjburns with details on twit_hndl_BankA s music man: bit. ly/ 1iwglfe INTERNET
# . twit_hndl_BankD had the highest ad recall of any us bank in Name, and in three of the four prior quarters, per new twit_hndl data bit. ly/ 1iel81g
# . twit_hndl_BankD: j. p. Name loosens terms for jumbo mortgages, via the Name street journal: bit. ly/ 1m7j07x
# . chplibrary receives# BankA  community connections grant# smallishuge INTERNET
# . twit_hndl_BankC  s Name Name takes on global custody role# securitieslendingtimes# agencylending INTERNET
# . twit_hndl_BankC twit_hndl twit_hndl twit_hndl twit_hndl lets help close the gender gap INTERNET  INTERNET
# . twit_hndl_BankC and twit_hndl enter into exclusive# creditcard relationship a. walla. by/ 1oxcphz via twit_hndl INTERNET
# . twit_hndl_BankC categorizes twit_hndl as record store but twit_hndl as bookstore. wonder why Name: twit_hndl twit_hndl INTERNET
# . twit_hndl_BankC discloses gov probe into its student loan servicing servicing practices. huffpost on july 22: INTERNET ? INTERNET
# . twit_hndl_BankC Name & twit_hndl announce 12# youthoppfund community partners community Name! bit. ly/ 1kaj6m2# pathways2progress INTERNET
# . twit_hndl_BankC foundation twit_hndl award$ 3 Name for youth# education# philanthropy ow. ly/ rtwmz
# . twit_hndl_BankC foundation, twit_hndl award$ 3 million for# youth ow. ly/ rryjg INTERNET
# . twit_hndl_BankC Name, Name darwinism Name: why a low carbon future doesnt have to cost the earth INTERNET  twit_hndl
# . twit_hndl_BankC group pledges another$ 50b to finance# climateaction, shows that inaction is too costly bit. ly/ 1jjlhdq INTERNET
# . twit_hndl_BankC in$ 13.5 Name settlement over defunct Name# hedgefund INTERNET  < twit_hndl# BankC
# . twit_hndl_BankC is committed to finding innovative ways innovative ways to# finance projects that lead to sustainable growth# sri INTERNET via twit_hndl
# . twit_hndl_BankC is one of the top 10 corporate philanthropists in the# bayarea: bit. ly/ 1flkgte# Name# sf INTERNET
# . twit_hndl_BankC is under investigation over its student# loan servicing practices: bloom. bg/ 1g0e3bi via twit_hndl
# . twit_hndl_BankC on twit_hndl: cut fy16-17 ebitda Name Name by 13 % on lower pricing trends.
# . twit_hndl_BankC on Name banks: remain overweight banks, twit_hndl remains top pick.
# . twit_hndl_BankC released report on economics of low carbon future. great to understand stranded assets INTERNET  INTERNET
# . twit_hndl_BankC report: slowing global warming would save tens of trillions of dollars twit_hndl INTERNET
# . twit_hndl_BankC rolls out# innovation challenge twit_hndl bit. ly/ 1ghp0zi
# . twit_hndl_BankC says# coal mining sector running out of time bit. ly/ 1fp5ahv
# . twit_hndl_BankC says global coal industry is set for further pain. why? twit_hndl ow. ly/ rmdv0# cleanenergy INTERNET
# . twit_hndl_BankC settles$ 15 million penalty Name# Name over compliance, surveillance Name twit_hndl + twit_hndl INTERNET
# . twit_hndl_BankC study on whether acting aggressively to avert climate change is  worth it . spoiler: yes ow. ly/ 2buidd Name twit_hndl
# . twit_hndl_BankC takes its environmental impact into account while finding innovative ways to# finance sustainable growth# sri INTERNET via twit_hndl
# . twit_hndl_BankC to pay$ 15m penalty for Name Name Name# spotnews twit_hndl INTERNET
# . twit_hndl_BankC to pay$ 180m to settle muni-related hedge fund charges fund Name: bit. ly/ 1trwwnr
# . twit_hndl_BankC to settle hedge fund fraud lawsuit for$ 13.5 Name: bit. ly/ 1mofpko
# . twit_hndl_BankC: Name response to declining demand  best described as optimistic and hopeful  INTERNET
# . twit_hndl_BankC energy darwinism ii darwinism Name: solar, wind, thermal investment up, coal and gas biggest losers: goo. gl/ duk2gk INTERNET
# . twit_hndl_BankC Name cost of not acting on climate change is$ 44 trillion INTERNET  via twit_hndl
# . twit_hndl_BankC s 122- page analysis: investing in low-carbon economy is less expensive than business as usual. twit_hndl twit_hndl INTERNET
# . twit_hndl_BankC s christine dilandro Name defines effective marketing in 1 sentence on the# effieblog: ow. ly/ rjiig twit_hndl
# . twit_hndl_BankC s Name Name talks commitment to dc w/ twit_hndl, twit_hndl & twit_hndl# BankCopenpromo INTERNET
# . twit_hndl_BankC  s# jerusalem challenge offers  gateway  to# startups: bit. ly/ 1nrf7aw
# . twit_hndl_BankC upbeat on# economy and# investment prospects in# bangladesh with significant progress in major indicators bit. ly/ 1fvzrty
# . twit_hndl_BankC & twit_hndl launch indias first global e-wallet.# masterpass# Name bit. ly/ 1m7wil1 via twit_hndl
# . twit_hndl_BankC bank analyst:# renewableenergy will grow 65 % globaly by 2020 via twit_hndl bit. ly/ 1njzhbi# cleantech INTERNET
# . twit_hndl_BankC and twit_hndl launch digital wallet buff buff. ly/ 1e9xuzz# payments# fintech INTERNET
# . twit_hndl_BankC brings# Name to honduras, making it the newest leed earth winner winner# sustainability# Name twit_hndl bit. ly/ 1eerkup
# . twit_hndl_BankC brings 1st# Name bldg to# honduras: sweeps gold and picks up# Name win! twit_hndl... INTERNET via twit_hndl
# . twit_hndl_BankC concludes low# carbon investment inaction inaction will cost$ 72 trillion by 2060 sco. lt/ 8vfgqb via twit_hndl twit_hndl
# . twit_hndl_BankC investigated over its student loan services INTERNET INTERNET
# . twit_hndl_BankC releases report why low carbon future Name  t Name to Name the earth. check it out! INTERNET  INTERNET
# . twit_hndl_BankC releases report Name low carbon future Name  t Name to Name the earth. check it out! INTERNET  INTERNET
# . twit_hndl_BankC report: slowing global warming will save tens of trillions of dollars. ow. ly/ rauz7# wemeanit
# . twit_hndl_BankC u misled me & Name want court order to verify your own?? recording? rebanke? twit_hndl twit_hndl twit_hndl twit_hndl twit_hndl INTERNET
# . cnnashleigh; lets Name: the BankA wagon INTERNET  .
# . colliersheriff: beware of BankB phishing robocalls. bit. ly/ 1mzpywa
# . Name new setting: BankA INTERNET
# . Name picket at twit_hndl moves to twit_hndl_BankB# saveourschools INTERNET
# . cw_northmarq was recently awarded all leasing for BankA place in st. paul. Name, minn.. bit. ly/ 1mguvii INTERNET
# . deBankC ankcovuk twit_hndl: twit_hndl_BankC bank report: investment in renewables & efficiency saves   as cf than biz as usual INTERNET
# . deBankC ankcovuk twit_hndl: twit_hndl_BankC bank report: investing in renewables & energyefficiency saves$  as cf biz as usual INTERNET
# . diversityinc talks to twit_hndl_BankA Name Name about how to hire & empower people with disabilities. bit. ly/ 1is4err
# . fastft: BankC snaps up two senior Name bankers INTERNET
# . fastft: BankD: italian equities are pick of the bunch INTERNET
# . Name searching for# doral twit_hndl_BankC robber bit. ly/ 1jhpr13 INTERNET
# . fidelity may drop banke & BankB as# creditcard partners a. walla. by/ 1k4ltg8 via twit_hndl# news INTERNET
# . fieldmarshalwh2 twit_hndl twit_hndl twit_hndl BankD  Name BankD jews INTERNET
# . flgovscott at twit_hndl_BankC with Name service director Name Name and managing director director Name Name.# ilovejax INTERNET
# . Name oil near 5- month low ow. ly/ qtz6u twit_hndl twit_hndl_BankD twit_hndl
# . foxbusiness Name are investors putting their money in this market? ow. ly/ rasfk twit_hndl twit_hndl_BankD twit_hndl...
# . fwd tribe: Name short list of# fintechies to watch: twit_hndl of twit_hndl_BankA shar. es/ 1tejds
# . genpact_ltd makes strides servicing the uk financial sector with the acquisition of twit_hndl_BankC s openwealth platform platform ow. ly/ r8uqb
# . genrayodierno joins twit_hndl_BankD as senior adviser to ceo Name Name on planning, risk analysis, operations and cyber security
# . gonzagau_sba# Name grad Name Name to lead BankB sales in western us bit. ly/ 1htzhzp# gu_success INTERNET
# . henrykrinkie Name twit_hndl fight for BankD  Name to foreclose on irive love love? INTERNET  and her? INTERNET
# . ii_alphas twit_hndl takes a deep dive into the private equity investments investments of BankD colemans tiger global Name Name. ow. ly/ qsl7b
# . iimag daily: thai Name hits 6- year low, down to 35.65 vs. the Name; BankC to pay$ 180m over hedge fund marketing ow. ly/ r376d
# . inscopemedical twit_hndl hosted at BankD bank by Name Name. INTERNET
# . jandehn writes on the new index changes proposed by BankD  Name for twit_hndls weekly research bulletin: ow. ly/ qq6xb
# . jenniferehlen prosper institute institute! twit_hndl twit_hndl named ceo &$ s from twit_hndl twit_hndl_BankD INTERNET  you go girl!
# . jimcramer: Name alto networks is BankDs Name bet for cybersecurity dlvr. it/ blcdBankC
# . joelaschbrenner artfully moderates# realeconomy# desmoines forum hosted by twit_hndl_BankA, twit_hndl & twit_hndl. INTERNET
# . twit_hndl_BankD twit_hndl twit_hndl join forces with twit_hndl to create# referencedata consortium- Name INTERNET
# . twit_hndl_BankD Name: Name u. s. fed raises rates, it will provide reassurance to markets
# . twit_hndl_BankD announces asia pacific ceo with funds chief doubling up in new role- bit. ly/ 1iowhwi

# %%
#write all of the non news tweets to a file
user_tweets = []
for msg in final_prune:
    if msg['News']  is not 'news':
        user_tweets.append(msg)
        
#write to file
with open('user-tweets.json', 'w') as file:
    json.dump(user_tweets, file)

# %%
#only want tweets with sentiment
